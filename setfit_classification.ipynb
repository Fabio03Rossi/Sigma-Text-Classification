# %% [markdown]
# ## SetFit Few-Shot Classification
#
# In questo notebook vengono mostrati i segmenti di codice e i procedimenti eseguiti per effettuare l'allenamento e l'inferenza del modello di classificazione.
#
# L'obiettivo è quello di classificare le note di chiusura degli interventi dei tecnici in base alle aree di guasto possibili della macchina. Queste comprendono: CASSETTE, CT, NE, NF, NV e SHUTTER.
# Il sistema deve poter categorizzare questi elementi testuali in maniera più o meno affidabile attraverso IA, includendo anche più di un'area per selezione.
#
# La task che quindi dobbiamo eseguire si ricongiunge ad una classificazione di testo multi-label.
#
# L'approccio utilizzato per la risoluzione consiste nel Few-Shot Learning, dove un modello IA di embedding viene allenato su un numero N di esempi reali per ogni singola label. Richiede più tempo e risorse hardware ma permette di ottenere risultati migliori in ambienti con pochi dati di allenamento e somprattutto categorizzazioni complesse come nel nostro caso.
#
# Utilizziamo diverse librerie di HuggingFace come Sentence-Transformers e SetFit per la definizione e l'allenamento del modello IA, insieme a Datasets per la manipolazione dei dati necessari agli step di training, validation e test.
#
#
#
# Qui di seguito nella prima cella definiamo la variabile d'ambiente per poter utilizzare la GPU durante l'allenamento.

# %%
import os

from sklearn.metrics import accuracy_score
os.environ["CUDA_VISIBLE_DEVICES"] = "GPU-7f4915f4-0bb6-f23e-021c-200070c6cf70"

# %% [markdown]
# Come primo step andiamo ad importare i 3 dataset necessari a completare l'operazione di training.
# Consistono nel dataset di training che presenta una varietà di dati labellizzati su cui il modello eseguirà l'allenamento, poi c'è il dataset di validation che contiene altri elementi labellizzati e conosciuti per validare l'accuratezza del modello in casi controllati.
# Infine abbiamo il dataset di test, contenente una grande collezione di note di chiusura senza labellizzazioni revisionate in cui il modello verrà messo contro le selezioni dei tecnici.
#
# I dataset sono estratti in pandas Dataframe da dei file Excel, e successivamente convertiti in Dataset eseguendo una pulizia sulle colonne ritenute non rilevanti per l'allenamento.
#
# Le label vengono estratte dalle colonne del dataset di training nel formato "{label} ground-truth".

# %%
import pandas as pd
from datasets import Dataset, Sequence

df_training = pd.read_excel("docs/new_tests/AllCombinedNotes-20250702-training.xlsx")
df_validation = pd.read_excel("docs/training_docs/ClosingNotes-sample-20250625-validation.xlsx")
df_test = pd.read_excel("docs/new_tests/ClosingNotes-sample-20250702-test.xlsx")

#df_test = df_test.replace(to_replace='None', value="'Something'")

dataset = Dataset.from_pandas(df_training.iloc[:, 9:16])
validation_dataset = Dataset.from_pandas(df_validation.iloc[:, 9:16])
#test_dataset = Dataset.from_pandas(df_test.iloc[:, 9:16])
test_dataset = Dataset.from_pandas(df_test.iloc[:, [0,1,2,3,4,5, 32, 49]])

features = dataset.column_names
features.remove("Closing Note")
features
# Out:
# ['CASSETTE ground-truth',
#  'CT ground-truth',
#  'NE ground-truth',
#  'NF ground-truth',
#  'NV ground-truth',
#  'SHUTTER ground-truth']

# %% [markdown]
# Eseguiamo ulteriori elaborazioni sui nostri dataset correnti, in cui rimappiamo le colonne delle singole label in una singola colonna "labels" contenente un vettore delle singole selezioni in formato binario.
#
# Successivamente rimuoviamo tutte le righe in cui le note di chiusura risultano vuote.

# %%
from datasets import Dataset

dataset = dataset.map(lambda entry: {"labels": [entry[label] for label in features]})
validation_dataset = validation_dataset.map(lambda entry: {"labels": [entry[label] for label in features]})
validation_dataset = validation_dataset.map(lambda entry: {"text": entry["Closing Note"]})
test_dataset = test_dataset.map(lambda entry: {"labels": [entry[label] for label in features]})
test_dataset = test_dataset.map(lambda entry: {"text": entry["Closing Note"]})
# Out:
# C:\Users\fbrossi\PyCharmMiscProject\.venv1\Lib\site-packages\datasets\utils\_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead.
#   obj.co_lnotab,  # for < python 3.10 [not counted in args]
# Map: 100%|██████████| 153/153 [00:00<00:00, 6173.26 examples/s]
# Map: 100%|██████████| 50/50 [00:00<00:00, 4066.14 examples/s]
# Map: 100%|██████████| 50/50 [00:00<00:00, 6482.70 examples/s]
# Map: 100%|██████████| 4453/4453 [00:00<00:00, 9375.20 examples/s]
# Map: 100%|██████████| 4453/4453 [00:00<00:00, 10794.65 examples/s]

# %%
dictionary = {"text": dataset["Closing Note"], "labels": dataset['labels']}
train_dataset = Dataset.from_dict(dictionary)

train_dataset = Dataset.from_pandas(train_dataset.to_pandas().dropna())
train_dataset = Dataset.from_pandas(train_dataset.to_pandas().replace(r'^\s*$', "Empty", regex=True))

dictionary = {"text": validation_dataset["Closing Note"], "labels": validation_dataset['labels']}
validation_dataset = Dataset.from_dict(dictionary)

validation_dataset = Dataset.from_pandas(validation_dataset.to_pandas().dropna())
validation_dataset = Dataset.from_pandas(validation_dataset.to_pandas().replace(r'^\s*$', "Empty", regex=True))

#dictionary = {"text": test_dataset["Closing Note"], "labels": test_dataset['labels']}
#test_dataset = Dataset.from_dict(dictionary)

test_dataset = Dataset.from_pandas(test_dataset.to_pandas().dropna())
test_dataset = Dataset.from_pandas(test_dataset.to_pandas().replace(r'^\s*$', "Empty", regex=True))

# %%
from setfit import get_templated_dataset, sample_dataset

train_dataset = get_templated_dataset(train_dataset, candidate_labels=features, sample_size=5, label_column="labels", multi_label=True, template="Il problema è del {}")

# %%
state = ["Guasto", "Funzionante"]

# Questo metodo aggiunge degli esempi sintetici su cui allenare il modello. Potrebbero aiutare
#train_state_dataset = sample_dataset(train_state_dataset)
#train_state_dataset = get_templated_dataset(train_state_dataset, candidate_labels=state, sample_size=10, template="L'ATM è {}")

#print(train_state_dataset['text'])

# %% [markdown]
# Qui di seguito definiamo la funzione per l'inizializzazione e il fetching del modello SetFit base da utilizzare pe effettuare il training.
# Questo comprende anche eventuali parametri relativi al modello stesso come specificare l'uso della GPU, definire una strategia di multi-label-selection, il parametro di temperatura e anche il numero di label

# %%
import torch
from setfit import SetFitModel
import os
os.environ["WANDB_DISABLED"] = "true"

# model instantiation for each trial run of the hyperparameter search
def model_init(params):
    #-- 39% accuracy
    #params = {"device": torch.device("cuda"), 'out_features': 6, 'temperature': 0.4}
    #return SetFitModel.from_pretrained("BAAI/bge-small-en-v1.5",
    #                                   multi_target_strategy="multi-output", params=params, labels=features)
    #params = {"device": torch.device("cuda"), 'out_features': 6, 'temperature': 0.2}
    #return SetFitModel.from_pretrained("SMARTICT/bge-small-en-v1.5-tr-rag-v1",
    #                                   multi_target_strategy="one-vs-rest", params=params, labels=features)
    #-- 40.48%
    params = {"device": torch.device("cuda"), 'out_features': 6, 'temperature': 0}
    return SetFitModel.from_pretrained("BAAI/bge-small-en-v1.5",
                                       multi_target_strategy="multi-output", params=params, labels=features)
    #params = {"device": torch.device("cuda"), 'out_features': 6, 'temperature': 0.2}
    #return SetFitModel.from_pretrained("sentence-transformers/all-MiniLM-L12-v2",
    #                                   multi_target_strategy="multi-output", params=params, labels=features, num_samples=len(features))

params = {"device": torch.device("cuda"), 'out_features': 2, 'temperature': 0.2}
model = SetFitModel.from_pretrained("sentence-transformers/all-MiniLM-L6-v2", params=params)

params = {"device": torch.device("cuda"), 'out_features': 6, 'temperature': 0}
#model2 = SetFitModel.from_pretrained("hello/model_no_5_new_data", params=params, labels=features)
#model.model_head
#SetFitModel.from_pretrained("SMARTICT/bge-small-en-v1.5-tr-rag-v1" -- 68%, sentence-transformers/all-MiniLM-L12-v2 -- 68%
    #"BAAI/bge-small-en-v1.5", sentence-transformers/all-roberta-large-v1
                                    #multi_target_strategy="one-vs-rest",
                                    #)
                                    #multi_target_strategy="classifier-chain",
                                    #num_samples=len(features),
                                    #use_differentiable_head=True,
                                    #head_params={"out_features": len(features)},
                                    #)
# Out:
# model_head.pkl not found on HuggingFace Hub, initialising classification head with random weights. You should TRAIN this model on a downstream task to use it for predictions and inference.

# %%
from setfit import TrainingArguments

args2 = TrainingArguments(
    # Optional training parameters:
    body_learning_rate=1.9859376752033417e-05,
    num_epochs=2,
    batch_size=6,
    warmup_proportion=0.2,
    sampling_strategy="unique",
    # Optional tracking/debugging parameters:
    logging_strategy="steps",
    logging_steps=1000,
    eval_strategy="steps",
    logging_first_step=True,
    eval_steps=1000,
    save_strategy="steps",
    save_steps=1000,
    run_name="finetune-setfit",
    load_best_model_at_end=True
)


args = TrainingArguments(
    batch_size=6,
    num_epochs=1,
    eval_strategy="epoch",
)
# Out:
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).

# %%
def compute_metrics(preds, labels):
    if hasattr(preds, "tolist"):
        preds = preds.tolist()

    if isinstance(preds[0], list):
        preds = [p[0] for p in preds]

    if isinstance(labels[0], list):
        labels = [l[0] for l in labels]

    return {"accuracy": accuracy_score(labels, preds)}

# %%
from google.cloud.aiplatform_v1 import Trial
from setfit import Trainer

trainer = Trainer(
    #model=model2,
    model_init=model_init,
    args=args2,
    train_dataset=train_dataset,
    eval_dataset=validation_dataset,
    column_mapping={"text": "text", "labels": "label"},
    #metric=compute_metrics
)

#best_run = trainer.hyperparameter_search(direction="maximize", hp_space=hp_space, n_trials=3)
# Out:
# Applying column mapping to the training dataset
# Applying column mapping to the evaluation dataset
# model_head.pkl not found on HuggingFace Hub, initialising classification head with random weights. You should TRAIN this model on a downstream task to use it for predictions and inference.
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# C:\Users\fbrossi\PyCharmMiscProject\.venv1\Lib\site-packages\datasets\utils\_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead.
#   obj.co_lnotab,  # for < python 3.10 [not counted in args]
# Map: 100%|██████████| 183/183 [00:00<00:00, 11587.70 examples/s]

# %%
#trainer2.train()

# %%
#trainer.apply_hyperparameters(best_run.hyperparameters, final_model=True)
trainer.train()
# Out:
# ***** Running training *****
#   Num unique pairs = 16836
#   Batch size = 6
#   Num epochs = 2
#     <div>
#
#       <progress value='5612' max='5612' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5612/5612 1:08:13, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1000</td>
#       <td>0.137200</td>
#       <td>0.058745</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.045400</td>
#       <td>0.049934</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.028600</td>
#       <td>0.042624</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.025400</td>
#       <td>0.042483</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.022800</td>
#       <td>0.037453</td>
#     </tr>
#   </tbody>
# </table><p>
# C:\Users\fbrossi\PyCharmMiscProject\.venv1\Lib\site-packages\sklearn\linear_model\_logistic.py:456: DeprecationWarning: scipy.optimize: The `disp` and `iprint` options of the L-BFGS-B solver are deprecated and will be removed in SciPy 1.18.0.
#   opt_res = optimize.minimize(
# C:\Users\fbrossi\PyCharmMiscProject\.venv1\Lib\site-packages\sklearn\linear_model\_logistic.py:456: DeprecationWarning: scipy.optimize: The `disp` and `iprint` options of the L-BFGS-B solver are deprecated and will be removed in SciPy 1.18.0.
#   opt_res = optimize.minimize(
# C:\Users\fbrossi\PyCharmMiscProject\.venv1\Lib\site-packages\sklearn\linear_model\_logistic.py:456: DeprecationWarning: scipy.optimize: The `disp` and `iprint` options of the L-BFGS-B solver are deprecated and will be removed in SciPy 1.18.0.
#   opt_res = optimize.minimize(
# C:\Users\fbrossi\PyCharmMiscProject\.venv1\Lib\site-packages\sklearn\linear_model\_logistic.py:456: DeprecationWarning: scipy.optimize: The `disp` and `iprint` options of the L-BFGS-B solver are deprecated and will be removed in SciPy 1.18.0.
#   opt_res = optimize.minimize(
# C:\Users\fbrossi\PyCharmMiscProject\.venv1\Lib\site-packages\sklearn\linear_model\_logistic.py:456: DeprecationWarning: scipy.optimize: The `disp` and `iprint` options of the L-BFGS-B solver are deprecated and will be removed in SciPy 1.18.0.
#   opt_res = optimize.minimize(
# C:\Users\fbrossi\PyCharmMiscProject\.venv1\Lib\site-packages\sklearn\linear_model\_logistic.py:456: DeprecationWarning: scipy.optimize: The `disp` and `iprint` options of the L-BFGS-B solver are deprecated and will be removed in SciPy 1.18.0.
#   opt_res = optimize.minimize(

# %%
def print_and_w(f, text):
    print(text)
    f.write(str(text))

# %%
metrics = trainer.evaluate()
with open("textual_output/metrics.txt", "a") as f:
    print_and_w(f, metrics)
# Out:
# ***** Running evaluation *****
# {'accuracy': 0.86}

# %%
def export_as_excel(filename, preds, bool):
    preds = map(lambda i: i.numpy().astype(numpy.int64).tolist(), preds)
    if bool:
        df_out = Dataset.to_pandas(test_dataset)
    else:
        df_out = Dataset.to_pandas(validation_dataset)

    print(preds)
    print(k.numpy().astype(numpy.int64).tolist() for k in preds)

    cassette, ct, ne, nf, nv, shutter = [], [], [], [], [], []


    for k in preds:
        cassette.append(int(k[0]))
        ct.append(int(k[1]))
        ne.append(int(k[2]))
        nf.append(int(k[3]))
        nv.append(int(k[4]))
        shutter.append(int(k[5]))

    #df_out.dropna(subset = ['Closing Note'], axis=0, inplace=True)
    df_out = pd.concat([df_out, pd.DataFrame({
                "CASSETTE Model": cassette,
                "CT Model": ct,
                "NE Model": ne,
                "NF Model": nf,
                "NV Model": nv,
                "SHUTTER Model": shutter
    })], axis=1)

    df_out = pd.concat([df_out, pd.DataFrame({
        "model_body": model2.model_body
    })], axis=0)

    df_out.to_excel(filename, index=False)

# %%
TP = 0  # True Positives
TN = 0  # True Negatives
FP = 0  # False Positives
FN = 0  # False Negatives

# %%
import numpy
from sklearn.metrics import classification_report
from sklearn.metrics import balanced_accuracy_score

"""Riscontrato apparato con fs 9301. Aperto dispensatore e rinvenuto biglietto di carta, scritto a penna, incastrato all'interno. Rimosso corpo estrano e resettato dspositivo. Carta stampante mancante, verrà la vigilanza in un secondo momento a sostituirla."""
"""Rimosse due banconote accartocciate. Controllo percorso banconote gruppo ricircolo con esito positivo."""

def elaborate_pred(i):
    result = []
    count = 0
    for k in i:
        if k == 1:
            result.append(str(features[count]))
        count += 1
    return result

def confusion_matrix(w_dataset):
    from sklearn.metrics import multilabel_confusion_matrix
    res = multilabel_confusion_matrix(w_dataset['labels'], preds).ravel().tolist()
    n = 4
    res = [res[i:i + n] for i in range(0, len(res), n)]
    res = {"CASSETTE": res[0], "CT": res[1], "NE": res[2], "NF": res[3], "NV": res[4], "SHUTTER": res[5]}
    return res

def percentage(array):
    if not len(array) == 0:
        return round((sum(array) / len(array)) * 100, 2)
    else:
        return 0

def repeating_w(f, w_dataset, TP, TN, FP, FN):
    CASSETTE, CT, NF, NE, NV, SHUTTER, CRM = [], [], [], [], [], [], []
    ac_cassette, ac_ct, ac_nf, ac_ne, ac_nv, ac_shutter = [], [], [], [], [], []
    ac_cassette_pred, ac_ct_pred, ac_nf_pred, ac_ne_pred, ac_nv_pred, ac_shutter_pred = [], [], [], [], [], []

    array = []
    count = 0
    for i in preds:
        i = i.numpy().astype(numpy.int64).tolist()
        matching = w_dataset['labels'][count]
        print_and_w(f, str(w_dataset['text'][count]) + '\n' + str(elaborate_pred(matching)) + '\n' + str(elaborate_pred(i)) + '\n' + str(pred_proba[count]) + '\n')
        array.append(w_dataset['labels'][count] == i)

        ac_cassette.append(matching[0])
        ac_cassette_pred.append(i[0])
        ac_ct.append(matching[1])
        ac_ct_pred.append(i[1])
        ac_ne.append(matching[2])
        ac_ne_pred.append(i[2])
        ac_nf.append(matching[3])
        ac_nf_pred.append(i[3])
        ac_nv.append(matching[4])
        ac_nv_pred.append(i[4])
        ac_shutter.append(matching[5])
        ac_shutter_pred.append(i[5])

        count2 = 0
        for k in matching:
            truth_selection = k == 1
            pred_selection = i[count2] == 1
            if truth_selection or pred_selection:
                match count2:
                    case 0:
                        CASSETTE.append(k == i[count2])
                    case 1:
                        CT.append(k == i[count2])
                    case 2:
                        NE.append(k == i[count2])
                    case 3:
                        NF.append(k == i[count2])
                    case 4:
                        NV.append(k == i[count2])
                    case 5:
                        SHUTTER.append(k == i[count2])
                    case 6:
                        CRM.append(k == i[count2])

            if truth_selection and pred_selection:
                TP += 1
            elif not truth_selection and not pred_selection:
                TN += 1
            elif not truth_selection and pred_selection:
                FP += 1
            elif truth_selection and not pred_selection:
                FN += 1

            count2 += 1
        count += 1
    result = "Total: " + str(round(accuracy_score(w_dataset["labels"], preds), 2)) + " - " + str(len(array)) + "\nCASSETTE: " + str(round(balanced_accuracy_score(ac_cassette, ac_cassette_pred), 2)) + " - " + str(len(CASSETTE)) + "\nCT: " + str(round(balanced_accuracy_score(ac_ct, ac_ct_pred), 2)) + " - " + str(len(CT)) + "\nNE: " + str(round(balanced_accuracy_score(ac_ne, ac_ne_pred), 2)) + " - " + str(len(NE)) + "\nNF: " + str(round(balanced_accuracy_score(ac_nf, ac_nf_pred), 2)) + " - " + str(len(NF)) + "\nNV: " + str(round(balanced_accuracy_score(ac_nv, ac_nv_pred),2)) + " - " + str(len(NV)) + "\nSHUTTER: " + str(round(balanced_accuracy_score(ac_shutter, ac_shutter_pred),2)) + " - " + str(len(SHUTTER)) + '\n\n'
    print_and_w(f, str(result))
    print_and_w(f, "TN, FP, FN, TP \n")
    print_and_w(f, str(confusion_matrix(w_dataset)) + '\n')

    return TP, TN, FP, FN

model2 = trainer.model
model2.save_pretrained("hello/model_delta_0610_17_23_validations")
#model2 = SetFitModel.from_pretrained("hello/MINImymodelUNIQUE") # 58.4
#model2 = SetFitModel.from_pretrained("hello/mymodel") # 58.75
#model2 = SetFitModel.from_pretrained("hello/model_no_1") #58.99
#model2 = SetFitModel.from_pretrained("hello/model_no_2") #58.13
#model2 = SetFitModel.from_pretrained("hello/model_gamma_0610_17_23")
#model2 = SetFitModel.from_pretrained("hello/model_no_6_24_06")
#model2 = SetFitModel.from_pretrained("hello/model_no_5_new_data")
#model2 = SetFitModel.from_pretrained("hello/model_no_6_24_06_epoch_2")

preds = model2.predict(validation_dataset['text'])
pred_proba = model2.predict_proba(validation_dataset['text'])

export_as_excel('closing_notes_output/ClosingNotesValidationModelDelta.xlsx', preds, False)
with open("textual_output/model_delta_validation.txt", 'w') as f:
    TP, TN, FP, FN = repeating_w(f, validation_dataset, TP, TN, FP, FN)
    print_and_w(f, "body_learning_rate: " + str(args2.body_learning_rate))
    print_and_w(f, "num_epochs: " + str(args2.num_epochs))
    print_and_w(f, "batch_size: " + str(args2.batch_size))
    print_and_w(f, "warmup_proportion: " + str(args2.warmup_proportion))
    print_and_w(f, "sampling_strategy: " + str(args2.sampling_strategy))
    print_and_w(f, classification_report(validation_dataset['labels'], preds, target_names=features, zero_division=0))
# Out:
# <map object at 0x000001C150BA0940>
# <generator object export_as_excel.<locals>.<genexpr> at 0x000001C1255EE670>
# Sostituzione cassetto rc 50 e regolazioni varie.
# ['CASSETTE ground-truth']
# ['CASSETTE ground-truth']
# tensor([[0.1190, 0.8810],
#         [0.9335, 0.0665],
#         [0.9668, 0.0332],
#         [0.9598, 0.0402],
#         [0.9647, 0.0353],
#         [0.9757, 0.0243]], dtype=torch.float64)
#
# Guasto riscontrato: banconote incastrate su cassetto rc2
# Sostituito cassetto rc da 50€ e cassetto unfit
# Controllato periferiche
# ['CASSETTE ground-truth']
# ['CASSETTE ground-truth']
# tensor([[0.1186, 0.8814],
#         [0.9332, 0.0668],
#         [0.9632, 0.0368],
#         [0.9622, 0.0378],
#         [0.9655, 0.0345],
#         [0.9762, 0.0238]], dtype=torch.float64)
#
# Eseguito sostituzione cassetto per molteplici errori.
# Riallineamento della parte lower,prove di movimentazione banconote con esito positivo
# ['CASSETTE ground-truth']
# ['CASSETTE ground-truth']
# tensor([[0.1183, 0.8817],
#         [0.9283, 0.0717],
#         [0.9669, 0.0331],
#         [0.9610, 0.0390],
#         [0.9658, 0.0342],
#         [0.9756, 0.0244]], dtype=torch.float64)
#
# Sostituito CT. Dai log risultavano inceppamenti su tutto il ct sia in fase di prelievo che di versamento. Test ok. ATM in servizio
# ['CT ground-truth']
# ['CT ground-truth']
# tensor([[0.9099, 0.0901],
#         [0.0768, 0.9232],
#         [0.9214, 0.0786],
#         [0.9148, 0.0852],
#         [0.9707, 0.0293],
#         [0.9718, 0.0282]], dtype=torch.float64)
#
# Rimossa banconota incastrata su st04 del trasporto e verifica generale dispensatore.  Prove di funzionamento con esito positivo.  ATM in regolare servizio utente
# ['CT ground-truth']
# ['CT ground-truth']
# tensor([[0.9103, 0.0897],
#         [0.0772, 0.9228],
#         [0.9295, 0.0705],
#         [0.9201, 0.0799],
#         [0.9725, 0.0275],
#         [0.9705, 0.0295]], dtype=torch.float64)
#
# Rimozione banconota incastrata in ingresso sul Cash transport, controllo generale e rimesso in servizio, verifiche finali funzionamento Mta.
# ['CT ground-truth']
# ['CT ground-truth']
# tensor([[0.9142, 0.0858],
#         [0.0767, 0.9233],
#         [0.9276, 0.0724],
#         [0.9141, 0.0859],
#         [0.9725, 0.0275],
#         [0.9713, 0.0287]], dtype=torch.float64)
#
# G.R. due banconote da 50€ inceppate all'interno del note escrow.
# Eseguita rimozione banconote e reset delle periferiche, esito positivo.
# Eseguita quadratura completa e test di prelievo e versamento insieme alla cassiera, esito positivo.
# ['NE ground-truth']
# ['NE ground-truth']
# tensor([[0.9568, 0.0432],
#         [0.9229, 0.0771],
#         [0.0929, 0.9071],
#         [0.9239, 0.0761],
#         [0.9482, 0.0518],
#         [0.9745, 0.0255]], dtype=torch.float64)
#
# Rimosse banconote logore incastrate nell'escrow e verifica generale. Prove finali con esito positivo.  ATM in regolare servizio utente
# ['NE ground-truth']
# ['NE ground-truth']
# tensor([[0.9552, 0.0448],
#         [0.9183, 0.0817],
#         [0.0924, 0.9076],
#         [0.9236, 0.0764],
#         [0.9476, 0.0524],
#         [0.9754, 0.0246]], dtype=torch.float64)
#
# Mta fs.
# Effettuato controllo dispensatore, riscontrate cinghie escrow fuori sede.
# Riposizionate e risolto inceppamento.
# Funzionalità ripristinate prove effettuate con esito positivo.
# ['NE ground-truth']
# ['NE ground-truth']
# tensor([[0.9579, 0.0421],
#         [0.9201, 0.0799],
#         [0.0930, 0.9070],
#         [0.9256, 0.0744],
#         [0.9480, 0.0520],
#         [0.9743, 0.0257]], dtype=torch.float64)
#
# Riscontrato corpo estraneo all'interno dello sfogliatore inferiore. Rimosso corpo estraneo. Pulizia. Test ok.
# ['NF ground-truth']
# ['NF ground-truth']
# tensor([[0.9620, 0.0380],
#         [0.9137, 0.0863],
#         [0.9208, 0.0792],
#         [0.0724, 0.9276],
#         [0.9566, 0.0434],
#         [0.9507, 0.0493]], dtype=torch.float64)
#
# Riscontrato MF inferiore con cinghia rotta causa inserimento corpo estraneo. Sostituzione NF inferiore. Test ok.
# ['NF ground-truth']
# ['NF ground-truth']
# tensor([[0.9638, 0.0362],
#         [0.9146, 0.0854],
#         [0.9195, 0.0805],
#         [0.0722, 0.9278],
#         [0.9588, 0.0412],
#         [0.9502, 0.0498]], dtype=torch.float64)
#
# Banconote inceppate nel NF inferiore per versamento con graffetta. Rimosso banconote e corpo estraneo. Prove di prelievo e versamento massivo con tool, ok. Prove di funzionamento ATM con clientela, ok.
# ['NF ground-truth']
# ['NF ground-truth']
# tensor([[0.9635, 0.0365],
#         [0.9135, 0.0865],
#         [0.9074, 0.0926],
#         [0.0721, 0.9279],
#         [0.9574, 0.0426],
#         [0.9516, 0.0484]], dtype=torch.float64)
#
# Eseguito pulizia e taratura validatore banconote.  Test finali con esito positivo
# ['NV ground-truth']
# ['NV ground-truth']
# tensor([[0.9664, 0.0336],
#         [0.9708, 0.0292],
#         [0.9535, 0.0465],
#         [0.9575, 0.0425],
#         [0.1559, 0.8441],
#         [0.9684, 0.0316]], dtype=torch.float64)
#
# Sostituito Validatore trovato con un sensore di thickness guasto, causa dei molti scarti. ATM rimesso in funzione e testato correttamente.
# ['NV ground-truth']
# ['NV ground-truth']
# tensor([[0.9651, 0.0349],
#         [0.9715, 0.0285],
#         [0.9537, 0.0463],
#         [0.9584, 0.0416],
#         [0.1559, 0.8441],
#         [0.9680, 0.0320]], dtype=torch.float64)
#
# Riscontrato validatore non ricircola correttamente. Sostituzione validatore banconote. Pulizia GRG. Test ok.
# ['NV ground-truth']
# ['NV ground-truth']
# tensor([[0.9642, 0.0358],
#         [0.9710, 0.0290],
#         [0.9562, 0.0438],
#         [0.9591, 0.0409],
#         [0.1565, 0.8435],
#         [0.9691, 0.0309]], dtype=torch.float64)
#
# Sostituzione shutter . Test ok .
# ['SHUTTER ground-truth']
# ['SHUTTER ground-truth']
# tensor([[0.9719, 0.0281],
#         [0.9678, 0.0322],
#         [0.9705, 0.0295],
#         [0.9541, 0.0459],
#         [0.9661, 0.0339],
#         [0.2102, 0.7898]], dtype=torch.float64)
#
# Al mio arrivo si riscontra macchina funzionante con anomalie su shutter che creava addebiti ai clienti. Dopo analisi si effettua la sostituzione e reset con prove di funzionamento con esito positivo.
# ['SHUTTER ground-truth']
# ['SHUTTER ground-truth']
# tensor([[0.9718, 0.0282],
#         [0.9673, 0.0327],
#         [0.9720, 0.0280],
#         [0.9578, 0.0422],
#         [0.9663, 0.0337],
#         [0.2079, 0.7921]], dtype=torch.float64)
#
# MTA trovato regolarmente in servizio senza anomalie. Controllo visivo del dispensatore, verifica file di log, sostituito shutter, test funzionali ok. Eseguite diverse operazioni in mia presenza di prelievo e versamento tutte con esito positivo.
# ['SHUTTER ground-truth']
# ['SHUTTER ground-truth']
# tensor([[0.9728, 0.0272],
#         [0.9690, 0.0310],
#         [0.9719, 0.0281],
#         [0.9571, 0.0429],
#         [0.9649, 0.0351],
#         [0.2070, 0.7930]], dtype=torch.float64)
#
# Atm in servizio.
# Il rumore è stato causato da ventolina di raffreddamento.
# È stata lubrifica e riposizionata.
# Guasto rientrato.
# Atm in servizio
# []
# []
# tensor([[0.9588, 0.0412],
#         [0.9600, 0.0400],
#         [0.9649, 0.0351],
#         [0.9634, 0.0366],
#         [0.9619, 0.0381],
#         [0.9599, 0.0401]], dtype=torch.float64)
#
# G.r. all'arrivo del tecnico atm in regolare servizio.
# Cassiera lamenta problema con cassa assegni che non si apre correttamente.
# Rilevato cassa assegni mancante di un dado sullo sportello e con angolo rovinato.
# Eseguita sostituzione cassa assegni e messa in servizio dell'apparato.
# []
# []
# tensor([[0.9577, 0.0423],
#         [0.9626, 0.0374],
#         [0.9662, 0.0338],
#         [0.9610, 0.0390],
#         [0.9544, 0.0456],
#         [0.9571, 0.0429]], dtype=torch.float64)
#
# Atm regolarmente in servizio con touch screen mal funzionante al mio arrivo.
# Tentativi di calibrazione e ripristino non risolutivi
# Eseguita sostituzione vetro touch e scheda controller.
# Eseguita taratura con successo.
# Testato più volte l'apparato esiti regolari.
# Rimesso in servizio ATM
# []
# []
# tensor([[0.9439, 0.0561],
#         [0.9646, 0.0354],
#         [0.9728, 0.0272],
#         [0.9717, 0.0283],
#         [0.9586, 0.0414],
#         [0.9566, 0.0434]], dtype=torch.float64)
#
# Trovata macchina in servizio, effettuata ricerca banconote solo in parte superiore del dispensatore come voluto dalla filiale. Nessuna banconota rinvenuta, lasciata macchina correttamente in servizio
# []
# []
# tensor([[0.9545, 0.0455],
#         [0.9622, 0.0378],
#         [0.9698, 0.0302],
#         [0.9673, 0.0327],
#         [0.9614, 0.0386],
#         [0.9582, 0.0418]], dtype=torch.float64)
#
# Guasto riscontrato:
# Macchina in servizio.
# Aperto ticket per ispezione apparato alla ricerca/ recupero di 750 euro.
#
# Intervento svolto:
# Ispezionato dispensatore.
# Non sono state rinvenute banconote in nessun punto del dispensatore.
# Rimessa in servizio ATM e atteso operazioni in modalità utente con esito positivo.
# []
# []
# tensor([[0.9566, 0.0434],
#         [0.9619, 0.0381],
#         [0.9649, 0.0351],
#         [0.9564, 0.0436],
#         [0.9562, 0.0438],
#         [0.9633, 0.0367]], dtype=torch.float64)
#
# GR richiesta ricerca banconote
# Effettuata ricerca banconote in tutto il dispensatore senza successo
# []
# []
# tensor([[0.9621, 0.0379],
#         [0.9638, 0.0362],
#         [0.9763, 0.0237],
#         [0.9704, 0.0296],
#         [0.9581, 0.0419],
#         [0.9609, 0.0391]], dtype=torch.float64)
#
# Nastro NE fuori posizione a seguito di un inceppamento. Riposizionato nastro NE. Riscontrato piatto CT RC2 con parti danneggiate, sostituito. Durante prove con tool, continue anomalie sul piatto del cassetto RC3. Sostituito cassetto RC3, anomalia rientrata. Prove massive di prelievo e versamento con tool, ok. Test di funzionamento ATM con clientela, ok.
# ['CASSETTE ground-truth', 'CT ground-truth', 'NE ground-truth']
# ['CT ground-truth', 'NE ground-truth']
# tensor([[0.5845, 0.4155],
#         [0.2739, 0.7261],
#         [0.4643, 0.5357],
#         [0.8864, 0.1136],
#         [0.9666, 0.0334],
#         [0.9808, 0.0192]], dtype=torch.float64)
#
# All'arrivo in servizio si riscontra dispensatore fuori servizio.
# Effettuato pulizia completa del dispensatore con sostituzione piatto AC del trasporto.
# Eseguito molteplici prove di movimentazione direttamente in zona cassetto scarti ,con esito positivo.
# Tutte le banconote risultano essere depositate in maniera corretta.
# Atm in servizio, prove ok
# ['CT ground-truth']
# ['CT ground-truth']
# tensor([[0.9067, 0.0933],
#         [0.0771, 0.9229],
#         [0.9281, 0.0719],
#         [0.9208, 0.0792],
#         [0.9728, 0.0272],
#         [0.9711, 0.0289]], dtype=torch.float64)
#
# Atm in fuori servizio. Riscontrato ricircolatore banconote in errore, causa trasporto banconote lower e cassetto deposito fit guasti. Effettuato sostituzione di entrambi. Verifica funzionamento atm con operazioni di prelievo e versamento banconote concluse tutte correttamente. Lasciato apparato in servizio regolare.
# ['CASSETTE ground-truth', 'CT ground-truth']
# ['CASSETTE ground-truth', 'CT ground-truth']
# tensor([[0.3556, 0.6444],
#         [0.2029, 0.7971],
#         [0.9290, 0.0710],
#         [0.9216, 0.0784],
#         [0.9756, 0.0244],
#         [0.9792, 0.0208]], dtype=torch.float64)
#
# G.R. deviatore del note feeder inferiore starato, link transport starato: quanto sopra genera frequenti inceppamenti con conseguenti retract ed eccessivi scarti.
# Eseguita taratura del deviatore del note feeder inferiore e del link transport, approfonditi test di collaudo con esito positivo.
# ['CT ground-truth', 'NF ground-truth']
# ['CT ground-truth', 'NF ground-truth']
# tensor([[0.9254, 0.0746],
#         [0.2337, 0.7663],
#         [0.8965, 0.1035],
#         [0.2492, 0.7508],
#         [0.9719, 0.0281],
#         [0.9655, 0.0345]], dtype=torch.float64)
#
# Guasto riscontrato:
# Dispensatore offline.
#
# Intervento svolto:
# Rimosse banconote incastrate da nv/ne/sf alto.
# L'inceppamento è stato causata da una graffetta rinvenuta nel NV.
# Inserite banconote in cassetto scarti.
# Eseguita pulizia generale macchina.
# Operazioni in modalità utente con esito positivo.
# ['NE ground-truth', 'NF ground-truth', 'NV ground-truth']
# ['NE ground-truth', 'NF ground-truth']
# tensor([[0.9602, 0.0398],
#         [0.9056, 0.0944],
#         [0.4524, 0.5476],
#         [0.3455, 0.6545],
#         [0.6864, 0.3136],
#         [0.9728, 0.0272]], dtype=torch.float64)
#
# Trovato atm fuori servizio, verificato errori: rimosso monete nello sfogliatore superiore, sostituito note escrow con nastro usurato, pulizia moduli grg, rimesso in servizio atm e verificato funzionamento con operazioni clienti banca, entrato di nuovo in errore: sostituito cash transport con piatto usurato, rimesso in servizio atm e verificato funzionamento con operazioni clienti banca
# ['CT ground-truth', 'NE ground-truth', 'NF ground-truth']
# ['CT ground-truth', 'NE ground-truth', 'NF ground-truth']
# tensor([[0.9333, 0.0667],
#         [0.3660, 0.6340],
#         [0.4431, 0.5569],
#         [0.3086, 0.6914],
#         [0.9660, 0.0340],
#         [0.9722, 0.0278]], dtype=torch.float64)
#
# Guasto riscontrato:Prelievo e versamento fuori servizio, anomalia cassetto RC1.
# Lavoro eseguito: verifica log e sostituito cassetto RC1 da 20€ ed eseguita configurazione. Eseguita pulizia generale ricircolatore e test funzionamento in modalità tecnico con esito positivo. Eseguito caricamento contabile da parte del cassiere e messa in servizio apparato con verifica funzionamento in modalità utente esito positivo.
# ['CASSETTE ground-truth']
# ['CASSETTE ground-truth']
# tensor([[0.1199, 0.8801],
#         [0.9250, 0.0750],
#         [0.9492, 0.0508],
#         [0.9557, 0.0443],
#         [0.9653, 0.0347],
#         [0.9782, 0.0218]], dtype=torch.float64)
#
# Cassetto rc1 rotto in uscita
# Sostituito cassetto
# Effettuate prove con Banconote
# Nessuna anomalia riscontrata
# Prove ok
# Macchina in servizio utente
# ['CASSETTE ground-truth']
# ['CASSETTE ground-truth']
# tensor([[0.1189, 0.8811],
#         [0.9323, 0.0677],
#         [0.9657, 0.0343],
#         [0.9615, 0.0385],
#         [0.9658, 0.0342],
#         [0.9756, 0.0244]], dtype=torch.float64)
#
# G.r. apparato in servizio . Eseguiti analisi con ST da remoto , verifica percentuali scarti nv , solenoidi e cinghie . Riscontrati problemi di sfogliamento cassetto RC 2.
#
# Sostituzione e configurazione cassetto RC2, test ok e messa in servizio apparato.
# ['CASSETTE ground-truth']
# ['CASSETTE ground-truth', 'NF ground-truth']
# tensor([[0.3930, 0.6070],
#         [0.9138, 0.0862],
#         [0.9276, 0.0724],
#         [0.4221, 0.5779],
#         [0.9203, 0.0797],
#         [0.9736, 0.0264]], dtype=torch.float64)
#
#
# Al mio arrivo l'atm risultava funzionante
# Riscontravo alcune banconote inserite erroneamente nei cassetti di altro taglio.
# Procedevo dopo aver analizzato i log io e il st alla sostituzione del cash trasport.
# Verifica funzionamento atm ok
# Rimessa in servizio.
#
# ['CT ground-truth']
# ['CT ground-truth']
# tensor([[0.8628, 0.1372],
#         [0.0835, 0.9165],
#         [0.9444, 0.0556],
#         [0.9076, 0.0924],
#         [0.9747, 0.0253],
#         [0.9719, 0.0281]], dtype=torch.float64)
#
# Guasto riscontrato: prelievo e versamento fuori servizio, ricircolatore banconote in errore 9521.
# Lavoro eseguito: verifica log e controlli visivi. Rimozione inceppamento di n.1 banconota da 50€ inceppata tra CT e RC 2 ed inserita nel cassetto AC -A. Sostituito CT causa cinghie usurate ed eseguite regolazioni. Messa in servizio apparato e verifica funzionamento in modalità utente con esito positivo.
# ['CT ground-truth']
# ['CASSETTE ground-truth', 'CT ground-truth']
# tensor([[0.4239, 0.5761],
#         [0.2101, 0.7899],
#         [0.7695, 0.2305],
#         [0.9078, 0.0922],
#         [0.9752, 0.0248],
#         [0.9806, 0.0194]], dtype=torch.float64)
#
# Gr: anomalia su plate rc2
# Versata banconota in verticale
# Rimosso inceppamento e effettuate prove di prelievo e versamento
# Prove ok
# Macchina in servizio utente
# ['CT ground-truth']
# ['CT ground-truth']
# tensor([[0.8866, 0.1134],
#         [0.0804, 0.9196],
#         [0.9099, 0.0901],
#         [0.8813, 0.1187],
#         [0.9687, 0.0313],
#         [0.9740, 0.0260]], dtype=torch.float64)
#
# Arrivato in filiale ATM fuori servizio con errore 5204
# Effettuato controllo e riscontrato nastro precassa escrow Arrivato a fine corsa.
# Provveduto quindi al riposizionamento corretto del nastro.
# Rimesso in servizio la macchina ed effettuato test di corretto funzionamento con esito OK
# ATM in regolare servizio
# ['NE ground-truth']
# ['NE ground-truth']
# tensor([[0.9565, 0.0435],
#         [0.9223, 0.0777],
#         [0.0936, 0.9064],
#         [0.9214, 0.0786],
#         [0.9452, 0.0548],
#         [0.9745, 0.0255]], dtype=torch.float64)
#
# Riscontro nastro escrow completamente ingarbugliato e tagliato in più punti con una banconota da 20 euro al suo interno. Rimossa e consegnata al personale. Sostituzione precassa escrow. Test di dispensazione e versamento con tool esito positivo. Rimessa in servizio con test reale esito positivo.
# ['NE ground-truth']
# ['NE ground-truth']
# tensor([[0.9561, 0.0439],
#         [0.9253, 0.0747],
#         [0.0933, 0.9067],
#         [0.9182, 0.0818],
#         [0.9488, 0.0512],
#         [0.9749, 0.0251]], dtype=torch.float64)
#
# Banconote incastrate nel NE a seguito di un versamento. Controllo di eventuali parti danneggiate o corpi estranei. Prove di prelievo e versamento massivo con tool, ok. Prove di funzionamento ATM con clientela, ok.
# ['NE ground-truth']
# ['NE ground-truth']
# tensor([[0.9708, 0.0292],
#         [0.9565, 0.0435],
#         [0.1960, 0.8040],
#         [0.9236, 0.0764],
#         [0.9606, 0.0394],
#         [0.9704, 0.0296]], dtype=torch.float64)
#
# Arrivato in filiale ATM fuori servizio con anomalia sul dispensatore
# Effettuato controllo e riscontrato 2 banconote da 50 euro incastrate nello sfogliatore inferiore e cinghia dello sfogliatore rotta.
# Provveduto quindi alla sostituzione dello sfogliatore
# Rimesso in servizio la macchina
# Test di corretto funzionamento con esito OK
# ATM in regolare servizio
# ['NF ground-truth']
# ['NF ground-truth']
# tensor([[0.9579, 0.0421],
#         [0.8945, 0.1055],
#         [0.9010, 0.0990],
#         [0.0735, 0.9265],
#         [0.9566, 0.0434],
#         [0.9535, 0.0465]], dtype=torch.float64)
#
# Causa presenza graffetta sostituzione Note Feeder Lower perché cinghia rovinata e successivamente Scheda Upper perché errore 6005. Riavvio apparato e verifiche finali funzionamento Mta con clienti Intesa SanPaolo.
# ['NF ground-truth']
# ['NF ground-truth']
# tensor([[0.9604, 0.0396],
#         [0.9092, 0.0908],
#         [0.9258, 0.0742],
#         [0.0732, 0.9268],
#         [0.9559, 0.0441],
#         [0.9528, 0.0472]], dtype=torch.float64)
#
# Rimosso banconota da slot con messa in servizio con test con esito positivo
# ['NF ground-truth']
# ['NE ground-truth']
# tensor([[0.9661, 0.0339],
#         [0.9115, 0.0885],
#         [0.1980, 0.8020],
#         [0.7006, 0.2994],
#         [0.9572, 0.0428],
#         [0.9721, 0.0279]], dtype=torch.float64)
#
# Riscontrato atm con prelievo e versamento fuori, ma non ci sono codici sul display del grg. Eseguendo un reset delle periferiche risulta in fuori servizio per il riempimento del cassetto l3. Controllo del grg, verifica dell'assenza di corpi estranei e pulizia. Sostituzione del validatore, controllo della taratura e calibratura e test positivi. Rimessa in servizio. L'atm resta con prelievo e versamento fuori servizio, necessita della quadratura per il ripristino.
# ['NV ground-truth']
# ['NV ground-truth']
# tensor([[0.9185, 0.0815],
#         [0.9718, 0.0282],
#         [0.9556, 0.0444],
#         [0.9630, 0.0370],
#         [0.1919, 0.8081],
#         [0.9688, 0.0312]], dtype=torch.float64)
#
# Il cliente ha riscontrato varie anomalie in fase di versamento classificando varie banconote come l2 e l3 , arrivato in filiale ho trovato l'atm parzialmente funzionante con versamento contante k.o causato da cassetto L3 pieno , controllando il validatore ho riscontrato varie anomalie sul componente che ho cambiato e rimesso in servizio utente . Eseguite prove di prelievo con esito ok ma il versamento non è stato possibile provarlo per via del cassetto L3 pieno .
# ['NV ground-truth']
# ['NV ground-truth']
# tensor([[0.8157, 0.1843],
#         [0.9683, 0.0317],
#         [0.9607, 0.0393],
#         [0.9581, 0.0419],
#         [0.2326, 0.7674],
#         [0.9726, 0.0274]], dtype=torch.float64)
#
# G.r non vengono rilevati i seriali dalle banconote prevalentemente sulle L3, eseguita sostituzione del validatore banconote con esito positivo.
# ['NV ground-truth']
# ['NV ground-truth']
# tensor([[0.9648, 0.0352],
#         [0.9717, 0.0283],
#         [0.9557, 0.0443],
#         [0.9590, 0.0410],
#         [0.1555, 0.8445],
#         [0.9685, 0.0315]], dtype=torch.float64)
#
# Gr. Prelievo e versamento fuori servizio. Eseguite prove con esito negativo. Lo shutter spesso va in time out in fase di chiusura.Sostituito shutter ed eseguite prove funzionamento con esito positivo
# ['SHUTTER ground-truth']
# ['SHUTTER ground-truth']
# tensor([[0.9727, 0.0273],
#         [0.9689, 0.0311],
#         [0.9695, 0.0305],
#         [0.9600, 0.0400],
#         [0.9671, 0.0329],
#         [0.2085, 0.7915]], dtype=torch.float64)
#
# G.R. deviatore del note feeder inferiore starato, link trasport starato in quanto:  genera frequenti inceppamenti con conseguenti retract ed eccessivi scarti.
# Eseguita taratura del deviatore del note feeder inferiore e del link transport, approfonditi test di collaudo con esito positivo.
# ['CT ground-truth', 'NF ground-truth']
# ['CT ground-truth', 'NF ground-truth']
# tensor([[0.9230, 0.0770],
#         [0.2232, 0.7768],
#         [0.8972, 0.1028],
#         [0.2610, 0.7390],
#         [0.9724, 0.0276],
#         [0.9659, 0.0341]], dtype=torch.float64)
#
# Al mio arrivo bancomat trovato in funzione. Eseguita pulizia e rimozione pezzi di carta su note escrow. Eseguita pulizia accurata del note validator con successive prove di funzionamento andate a buon. Macchina lasciata in servizio.
# ['NE ground-truth', 'NV ground-truth']
# ['NE ground-truth', 'NV ground-truth']
# tensor([[0.9656, 0.0344],
#         [0.9491, 0.0509],
#         [0.3940, 0.6060],
#         [0.9442, 0.0558],
#         [0.3987, 0.6013],
#         [0.9746, 0.0254]], dtype=torch.float64)
#
# Riscontrato apparato regolarmente acceso ed online ma con apparato cash_in in hw error 6006.
# Dalla diagnostica hw effettuata è risultato un malfunzionamento dello shutter banconote in fase di open/closed generando frequenti mancate erogazioni.
# Inoltre dall'analisi dello storico eventi è stata riscontrata un'alta percentuale di Banconote non ricircolate.
# Effettuata la sostituzione dello shutter Banconote e del Note validator.
# Riavvio Mta e prove transazionali di prelievo e versamento con esito regolare.
# Bancomat in regola servizio.
# ['NV ground-truth', 'SHUTTER ground-truth']
# ['SHUTTER ground-truth']
# tensor([[0.9694, 0.0306],
#         [0.9710, 0.0290],
#         [0.9757, 0.0243],
#         [0.9615, 0.0385],
#         [0.6869, 0.3131],
#         [0.4142, 0.5858]], dtype=torch.float64)
#
# Sostituito trasporto banconote e validatore ed effettuate prove di funzionamento.
# ['CT ground-truth', 'NV ground-truth']
# ['CT ground-truth']
# tensor([[0.9294, 0.0706],
#         [0.3250, 0.6750],
#         [0.9431, 0.0569],
#         [0.9424, 0.0576],
#         [0.5959, 0.4041],
#         [0.9682, 0.0318]], dtype=torch.float64)
#
# Total: 0.86 - 50
# CASSETTE: 0.93 - 9
# CT: 1.0 - 13
# NE: 0.99 - 11
# NF: 0.94 - 11
# NV: 0.85 - 10
# SHUTTER: 1.0 - 5
#
#
# TN, FP, FN, TP
#
# {'CASSETTE': [41, 1, 1, 7], 'CT': [37, 0, 0, 13], 'NE': [39, 1, 0, 10], 'NF': [39, 1, 1, 9], 'NV': [40, 0, 3, 7], 'SHUTTER': [45, 0, 0, 5]}
#
# body_learning_rate: (1.9859376752033417e-05, 1.9859376752033417e-05)
# num_epochs: (2, 2)
# batch_size: (6, 6)
# warmup_proportion: 0.2
# sampling_strategy: unique
#                        precision    recall  f1-score   support
#
# CASSETTE ground-truth       0.88      0.88      0.88         8
#       CT ground-truth       1.00      1.00      1.00        13
#       NE ground-truth       0.91      1.00      0.95        10
#       NF ground-truth       0.90      0.90      0.90        10
#       NV ground-truth       1.00      0.70      0.82        10
#  SHUTTER ground-truth       1.00      1.00      1.00         5
#
#             micro avg       0.94      0.91      0.93        56
#             macro avg       0.95      0.91      0.93        56
#          weighted avg       0.95      0.91      0.92        56
#           samples avg       0.84      0.83      0.83        56

# %%
preds = model2.predict(test_dataset['text'])
pred_proba = model2.predict_proba(test_dataset['text'])

TP, TN, FP, FN = 0,0,0,0

export_as_excel('cosing_notes_output/ClosingNotesOutputModelDeltaTest.xlsx', preds, True)
with open("textual_output/model_delta_new_test_0207.txt", 'w') as f:
    TP, TN, FP, FN = repeating_w(f, test_dataset, TP, TN, FP, FN)
    print_and_w(f, "body_learning_rate: " + str(args2.body_learning_rate))
    print_and_w(f, "num_epochs: " + str(args2.num_epochs))
    print_and_w(f, "batch_size: " + str(args2.batch_size))
    print_and_w(f, "warmup_proportion: " + str(args2.warmup_proportion))
    print_and_w(f, "sampling_strategy: " + str(args2.sampling_strategy))
    print_and_w(f, classification_report(test_dataset['labels'], preds, target_names=features, zero_division=0))
# Out:
# <map object at 0x000001C136895C60>
# <generator object export_as_excel.<locals>.<genexpr> at 0x000001C198D91630>
# Guasto
# Piatto del ct AC-B con dentino rotto causa malfunzionamenti.
# Soluzione
# Sostituito parte danneggiata.
# Test di dispensazione e deposito con esito positivo.
# Test di prelievo e versamento con esito positivo.
# ['CT ground-truth']
# ['CT ground-truth']
# tensor([[0.9120, 0.0880],
#         [0.0809, 0.9191],
#         [0.8679, 0.1321],
#         [0.8932, 0.1068],
#         [0.9686, 0.0314],
#         [0.9735, 0.0265]], dtype=torch.float64)
#
# Rimosso banconote incastrate in area escrow.
# Eseguito test di prelievo e deposito con esito positivo
# Atm rimesso in servizio e funzionante
# ['NE ground-truth']
# ['NE ground-truth', 'NF ground-truth']
# tensor([[0.9654, 0.0346],
#         [0.8841, 0.1159],
#         [0.2551, 0.7449],
#         [0.2861, 0.7139],
#         [0.9578, 0.0422],
#         [0.9704, 0.0296]], dtype=torch.float64)
#
# ATM in servizio regolare. Attesa disponibilità apparato ed ispezionata parte superiore ricircolatore con recupero dei log degli ultimi 3gg. Riscontrate varie dispensazioni con scarto elevato di bnc da 20e per eccessivo disallineamento (skew). Sostituito quindi cassetto, bonificato apparato con aria compressa e rimesso in servizio sportello. Assistito a varie operazioni cash avvenute tutte con esito positivo. Lasciato apparato in servizio regolare.
# ['CASSETTE ground-truth']
# ['CASSETTE ground-truth']
# tensor([[0.1813, 0.8187],
#         [0.9175, 0.0825],
#         [0.9118, 0.0882],
#         [0.9073, 0.0927],
#         [0.9686, 0.0314],
#         [0.9785, 0.0215]], dtype=torch.float64)
#
# Rimosso pezzo di banconota che occupava sensore dal feeder superiore. Test ok. ATM in servizio
# ['NF ground-truth']
# ['NF ground-truth']
# tensor([[0.9613, 0.0387],
#         [0.9104, 0.0896],
#         [0.9113, 0.0887],
#         [0.0740, 0.9260],
#         [0.9591, 0.0409],
#         [0.9507, 0.0493]], dtype=torch.float64)
#
# Guasto riscontrato: cassetto rc rotto
# Sostituito cassetto rc da 50€ rotto
# Collaudo con esito positivo
# ['CASSETTE ground-truth']
# ['CASSETTE ground-truth']
# tensor([[0.1176, 0.8824],
#         [0.9202, 0.0798],
#         [0.9583, 0.0417],
#         [0.9593, 0.0407],
#         [0.9660, 0.0340],
#         [0.9777, 0.0223]], dtype=torch.float64)
#
# Arrivato in filiale ATM fuori servizio con anomalia sul dispensatore
# Effettuato controllo e riscontrato problema sul CT che ho sostituito e sul motore MC06 del CT che ho sostituito.
# Rimesso in servizio la macchina ed effettuato test di corretto funzionamento con esito OK
# Atm in regolare servizio
# ['CT ground-truth']
# ['CT ground-truth']
# tensor([[0.8963, 0.1037],
#         [0.0786, 0.9214],
#         [0.8846, 0.1154],
#         [0.8986, 0.1014],
#         [0.9708, 0.0292],
#         [0.9732, 0.0268]], dtype=torch.float64)
#
# Filiale segnala ammanco. Controllato intero dispesatore e nessuna banconota trovata. Segnalato alla filiale di aprire ticket contabilità per ulteriori analisi
# []
# []
# tensor([[0.9049, 0.0951],
#         [0.8731, 0.1269],
#         [0.9209, 0.0791],
#         [0.9512, 0.0488],
#         [0.9360, 0.0640],
#         [0.9818, 0.0182]], dtype=torch.float64)
#
# Arrivato in filiale ATM fuori servizio con anomalia 950E
# Effettuato controllo e riscontrato leva 10 lasciata staccata.
# Rimesso in servizio la macchina ed effettuato test di corretto funzionamento con esito OK
# ATM in regolare servizio
# ['NE ground-truth']
# []
# tensor([[0.9446, 0.0554],
#         [0.9365, 0.0635],
#         [0.8861, 0.1139],
#         [0.9265, 0.0735],
#         [0.9592, 0.0408],
#         [0.9462, 0.0538]], dtype=torch.float64)
#
# Filiale segnala ammanco di 2 pezzi 50€ . Controllato intero bancomat e nessuna banconota trovata. Bancomat funzionante. Segnalato di aprire ticket contabilità per ulteriori analisi
# []
# []
# tensor([[0.9435, 0.0565],
#         [0.9389, 0.0611],
#         [0.9565, 0.0435],
#         [0.9611, 0.0389],
#         [0.9424, 0.0576],
#         [0.9744, 0.0256]], dtype=torch.float64)
#
# GR: rimosso 4 banconote inceppate su rullo Escrow e riposizionato completamente il nastro arancione. Riavviato e testato atm con successo.
# ['NE ground-truth']
# ['NE ground-truth']
# tensor([[0.9581, 0.0419],
#         [0.9168, 0.0832],
#         [0.0923, 0.9077],
#         [0.9234, 0.0766],
#         [0.9504, 0.0496],
#         [0.9744, 0.0256]], dtype=torch.float64)
#
# ATM trovato fuori servizio, trovata moneta versata, rimossa banconota incastrata, eseguite diverse prove con esito positivo, ATM in regolare funzionamento.
# ['NF ground-truth']
# ['NE ground-truth']
# tensor([[0.9698, 0.0302],
#         [0.9409, 0.0591],
#         [0.2272, 0.7728],
#         [0.9382, 0.0618],
#         [0.9674, 0.0326],
#         [0.9701, 0.0299]], dtype=torch.float64)
#
# G.r banconote inceppate su sfogliatore inferiore causa elastico.  Rimosso elastico e banconote inceppate da sfogliatore inferiore  test di dispensazione e versamento banconote con esito positivo
# ['NF ground-truth']
# ['NF ground-truth']
# tensor([[0.9614, 0.0386],
#         [0.9044, 0.0956],
#         [0.8999, 0.1001],
#         [0.0737, 0.9263],
#         [0.9518, 0.0482],
#         [0.9529, 0.0471]], dtype=torch.float64)
#
# Al mio arrivo si riscontra macchina parzialmente funzionante con dispensatore bloccato per nastri escrow fuoriusciti. Effettuato ripristino e test di funzionamento con esito positivo.
# ['NE ground-truth']
# ['NE ground-truth']
# tensor([[0.9592, 0.0408],
#         [0.9291, 0.0709],
#         [0.0934, 0.9066],
#         [0.9226, 0.0774],
#         [0.9482, 0.0518],
#         [0.9749, 0.0251]], dtype=torch.float64)
#
# ATM trovato fuori servizio, riposizionate cinghie escrow, eseguite diverse prove con esito positivo, ATM in regolare funzionamento.
# ['NE ground-truth']
# ['NE ground-truth']
# tensor([[0.9591, 0.0409],
#         [0.9180, 0.0820],
#         [0.0934, 0.9066],
#         [0.9263, 0.0737],
#         [0.9512, 0.0488],
#         [0.9735, 0.0265]], dtype=torch.float64)
#
# Rimozione inceppamento nel cassetto AC.
# Verifiche, test e monitoraggio con esito positivo.
# ATM in servizio.
# ['CASSETTE ground-truth']
# ['CASSETTE ground-truth']
# tensor([[0.1182, 0.8818],
#         [0.9311, 0.0689],
#         [0.9615, 0.0385],
#         [0.9598, 0.0402],
#         [0.9691, 0.0309],
#         [0.9759, 0.0241]], dtype=torch.float64)
#
# GR: controllato ricircolatore banconote e testato reset multipli. Effettuato sostituzione Escrow per errore sul motorino inferiore ed eseguito pulizia generale meccanica dispensatore. Riavviato atm e testato prelievo con successo.
# ['NE ground-truth']
# ['NE ground-truth']
# tensor([[0.9125, 0.0875],
#         [0.7611, 0.2389],
#         [0.1308, 0.8692],
#         [0.9371, 0.0629],
#         [0.9491, 0.0509],
#         [0.9779, 0.0221]], dtype=torch.float64)
#
# Guasto riscontrato: mta regolarmente in servizio
# Lavoro eseguito: la filiale riferisce che è stata contattata da help desk e che le deficienze contabili afferiscono a disallineamenti contabili già risolti.  Effettuata pulizia e verifica parte upper del dispensatore
# []
# []
# tensor([[0.9545, 0.0455],
#         [0.9442, 0.0558],
#         [0.9558, 0.0442],
#         [0.8756, 0.1244],
#         [0.9645, 0.0355],
#         [0.9664, 0.0336]], dtype=torch.float64)
#
# Atm trovato in servizio.
# Eseguita ispezione ricircolatore e verifica log dove si evidenzia un inceppamento risolto in autonomia.
# Da verifica con tavolo intesa il ticket risulta chiuso sul service now.
# []
# []
# tensor([[0.9209, 0.0791],
#         [0.9277, 0.0723],
#         [0.9437, 0.0563],
#         [0.9614, 0.0386],
#         [0.9632, 0.0368],
#         [0.9733, 0.0267]], dtype=torch.float64)
#
# ATM trovato fuori servizio, rimosse banconote inceppate nell'escrow, eseguite diverse prove con esito positivo, ATM in regolare funzionamento.
# ['NE ground-truth']
# ['NE ground-truth']
# tensor([[0.9575, 0.0425],
#         [0.9172, 0.0828],
#         [0.0925, 0.9075],
#         [0.9259, 0.0741],
#         [0.9511, 0.0489],
#         [0.9744, 0.0256]], dtype=torch.float64)
#
# Guasto riscontrato: Atm in servizio
#
# Lavoro eseguito: effettuate verifiche e pulizia.
# Le operazioni lamentate dal cliente non riguardano un guasto dovuto al bancomat ma ha la procedura delle transazioni off-line
#
# effettuati test sia in modalità tecnico che utente con esito positivo
#
#
# []
# []
# tensor([[0.9521, 0.0479],
#         [0.9238, 0.0762],
#         [0.8571, 0.1429],
#         [0.9361, 0.0639],
#         [0.9503, 0.0497],
#         [0.9753, 0.0247]], dtype=torch.float64)
#
# Gr. Versamento e prelievo fuori servizio causa inceppamento. Rimossa n.1 bnc euro 50,00 sotto note feeder inferiore. Ispezionate tutte le parti macchina,  pulizia parti superiore macchina per sporco eccessivo. Prove funzionamento con esito positivo.
# ['NF ground-truth']
# ['NF ground-truth']
# tensor([[0.9591, 0.0409],
#         [0.9064, 0.0936],
#         [0.9169, 0.0831],
#         [0.0740, 0.9260],
#         [0.9542, 0.0458],
#         [0.9537, 0.0463]], dtype=torch.float64)
#
# Gr. Scarti eccessivi. sostituito NV causa n. 2 rulli di trasporto bloccati.
# ['NV ground-truth']
# ['CT ground-truth']
# tensor([[0.9272, 0.0728],
#         [0.2833, 0.7167],
#         [0.9524, 0.0476],
#         [0.9501, 0.0499],
#         [0.6495, 0.3505],
#         [0.9680, 0.0320]], dtype=torch.float64)
#
# Gr. Versamento e prelievo fuori servizio causa inceppamento. Rimosso banconote dentro feeder superiore. Ripristinato allineamento cinghie fuori sede della precassa. Ripristinato funzionamento.
# ['NE ground-truth']
# ['NF ground-truth']
# tensor([[0.9609, 0.0391],
#         [0.9095, 0.0905],
#         [0.9194, 0.0806],
#         [0.0733, 0.9267],
#         [0.9560, 0.0440],
#         [0.9528, 0.0472]], dtype=torch.float64)
#
# Filiale segnala che molte banconote vengono scartate in fase di dispensazione e finiscono piegate nel cassetto AC. Dall'analisi dei log si riscontrano frequenti banconote erogate con skew alto e space too narrow. Post verifiche hw effettuata sostituzione Note feeder inferiore e rimessa in servizio con 3 prove di prelievo avvenute con esito positivo.
# ['NF ground-truth']
# ['NF ground-truth']
# tensor([[0.5352, 0.4648],
#         [0.8962, 0.1038],
#         [0.9014, 0.0986],
#         [0.2348, 0.7652],
#         [0.9655, 0.0345],
#         [0.9726, 0.0274]], dtype=torch.float64)
#
# Rimosse banconote inceppate in area Nf inferiore. Verificato trasporto superiore e log senza riscontrare altri problemi. Non è stato possibile ispezionare i cassetti causa blocco 36h. Rimessa in servizio con prove di prelievo/versamento avvenute con successo.
# ['NF ground-truth']
# ['CT ground-truth', 'NF ground-truth']
# tensor([[0.9276, 0.0724],
#         [0.2620, 0.7380],
#         [0.8834, 0.1166],
#         [0.2212, 0.7788],
#         [0.9718, 0.0282],
#         [0.9662, 0.0338]], dtype=torch.float64)
#
# Guasto
# Banconote incastrate all'interno dello sfogliatore inferiore.
# Soluzione
# Rimosso inceppamento e reset dispositivo.
# Test di prelievo e versamento con esito positivo.
#
#
# ['NF ground-truth']
# ['NF ground-truth']
# tensor([[0.9604, 0.0396],
#         [0.9036, 0.0964],
#         [0.9046, 0.0954],
#         [0.0725, 0.9275],
#         [0.9550, 0.0450],
#         [0.9539, 0.0461]], dtype=torch.float64)
#
# Guasto
# Anomalia 42d1 persiste a seguito di reset.
# Soluzione
# Sostituito cassetto RC1.
# Test di prelievo e versamento con esito positivo
# ['CASSETTE ground-truth']
# ['CASSETTE ground-truth']
# tensor([[0.1196, 0.8804],
#         [0.9308, 0.0692],
#         [0.9582, 0.0418],
#         [0.9587, 0.0413],
#         [0.9643, 0.0357],
#         [0.9769, 0.0231]], dtype=torch.float64)
#
# Effettuata verifica e ispezionamento mta per recupero banconote,  nessuna banconota presente nella macchina.  Effettuata pulizia e verificato funzionamento in modalità utente con esito positivo
# []
# []
# tensor([[0.9601, 0.0399],
#         [0.9600, 0.0400],
#         [0.9628, 0.0372],
#         [0.9699, 0.0301],
#         [0.9585, 0.0415],
#         [0.9613, 0.0387]], dtype=torch.float64)
#
# Effettuata verifica e ispezionamento mta per recupero banconote,  nessuna banconota presente nella macchina.  Effettuata pulizia e verificato funzionamento in modalità utente con esito positivo
# []
# []
# tensor([[0.9601, 0.0399],
#         [0.9600, 0.0400],
#         [0.9628, 0.0372],
#         [0.9699, 0.0301],
#         [0.9585, 0.0415],
#         [0.9613, 0.0387]], dtype=torch.float64)
#
# Guasto riscontrato: errore 2031 carrello dispensatore superiore sganciato
# Lavoro eseguito: riposizionamento carrello dispensatore e verificato funzionamento.  Effettuato prelievo e analisi log dispensatore grg.  Rimessa in servizio mta in modalità utente e verificato funzionamento con esito positivo
# []
# []
# tensor([[0.9038, 0.0962],
#         [0.9097, 0.0903],
#         [0.9211, 0.0789],
#         [0.7970, 0.2030],
#         [0.9740, 0.0260],
#         [0.9673, 0.0327]], dtype=torch.float64)
#
# Al mio arrivo rilevo mta con grg con errore 9520.
# Rilevata n.1 banconota da 20 euro inceppata nel cash transport zona sopra il cassetto rc 20 euro e posizionamento della stessa nel cassetto AC scomparto A. Eseguita pulizia cash transport, cassetti e grg.
# Eseguite numerose prove di erogazione e deposito banconote tutte portate a termine con esito regolare.
# Prova di prelievo contanti con esito regolare .
# ['CT ground-truth']
# ['CASSETTE ground-truth', 'CT ground-truth']
# tensor([[0.4176, 0.5824],
#         [0.1724, 0.8276],
#         [0.8922, 0.1078],
#         [0.9142, 0.0858],
#         [0.9762, 0.0238],
#         [0.9799, 0.0201]], dtype=torch.float64)
#
# Guasto riscontrato: banconote inceppate nel cash trasport
# Lavoro eseguito: rimosse banconote inceppate,  effettuata pulizia dispensatore e verificato funzionamento in modalità utente con esito positivo
# ['CT ground-truth']
# ['CT ground-truth']
# tensor([[0.9055, 0.0945],
#         [0.0806, 0.9194],
#         [0.8004, 0.1996],
#         [0.9093, 0.0907],
#         [0.9714, 0.0286],
#         [0.9754, 0.0246]], dtype=torch.float64)
#
# G.r. errata classificazione banconote vere come L2, eseguita pulizia e taratura sensori test funzionalità ok
# ['NV ground-truth']
# []
# tensor([[0.9590, 0.0410],
#         [0.9280, 0.0720],
#         [0.8840, 0.1160],
#         [0.9679, 0.0321],
#         [0.9686, 0.0314],
#         [0.9715, 0.0285]], dtype=torch.float64)
#
# Filiale segnala molteplici bip anomali durante prelievi o versamenti e clienti lamentano la mancata restituzione del denaro.
# Effettuata sostituzione bocchetta ed effettuati test con esito positivo.
# ['SHUTTER ground-truth']
# ['NF ground-truth']
# tensor([[0.9611, 0.0389],
#         [0.9279, 0.0721],
#         [0.8823, 0.1177],
#         [0.2122, 0.7878],
#         [0.9625, 0.0375],
#         [0.9595, 0.0405]], dtype=torch.float64)
#
# G.r. touchscreen monitor interno ko, eseguita sostituzione e taratura touch, riavviata macchina test funzionalità ok
# []
# []
# tensor([[0.9479, 0.0521],
#         [0.9527, 0.0473],
#         [0.9767, 0.0233],
#         [0.9578, 0.0422],
#         [0.9143, 0.0857],
#         [0.9348, 0.0652]], dtype=torch.float64)
#
# ATM fuori servizio. Cinghie escrow fuori sede, riposiziate. Si riscontra anomalia dopo un versamento, le banconote sono entrate storte nel cassetto dovuto anche al fatto che i cassetti da ricircolo sono pieni. Al primo prelievo ha inceppato mandando fuori sede le cinghie. Richiesto scarico dell'atm in quanto troppo carico e le operazioni di versamento non potrebbero permettere il corretto ricircolo delle banconote. Test massivi ok, test con atm in servizio ok. ATM in regolare servizio
# ['NE ground-truth']
# ['NE ground-truth']
# tensor([[0.6978, 0.3022],
#         [0.8943, 0.1057],
#         [0.1718, 0.8282],
#         [0.9255, 0.0745],
#         [0.9571, 0.0429],
#         [0.9805, 0.0195]], dtype=torch.float64)
#
# ATM fuori servizio. Banconota incastrata in area escrow. Rimossa, riposizionato nastro. Eseguito controllo macchina e log senza riscontrare problematiche, cassetti pieni i quali non permettono il corretto ricircolo della banconote da 50 e da 20. Consigliato alla filiale di scaricare il bancomat. Prove con atm in servizio con esito positivo. ATM in regolare servizio
# ['NE ground-truth']
# ['NE ground-truth', 'NF ground-truth']
# tensor([[0.9648, 0.0352],
#         [0.9129, 0.0871],
#         [0.2132, 0.7868],
#         [0.3723, 0.6277],
#         [0.9643, 0.0357],
#         [0.9697, 0.0303]], dtype=torch.float64)
#
# Guasto riscontrato:
# Sfogliatore inferiore malfunzionante.
# Intervento effettuato:
# Sostituzione sfogliatore inferiore.
# Taratura link trasport.
# Effettuato prove tutte con esito positivo.
# ['NF ground-truth']
# ['CT ground-truth', 'NF ground-truth']
# tensor([[0.9292, 0.0708],
#         [0.2796, 0.7204],
#         [0.8879, 0.1121],
#         [0.2124, 0.7876],
#         [0.9698, 0.0302],
#         [0.9642, 0.0358]], dtype=torch.float64)
#
# Gr frequenti disconnessioni grg
# Sostituzione scheda main lower.
# Verifiche e prove di funzionamento.
# []
# []
# tensor([[0.9576, 0.0424],
#         [0.9660, 0.0340],
#         [0.9451, 0.0549],
#         [0.9684, 0.0316],
#         [0.9278, 0.0722],
#         [0.9653, 0.0347]], dtype=torch.float64)
#
# Nessuna banconota ritrovata. Effettuata verifica al ricircolatore e prove di funzionamento. Apparato ora regolarmente in servizio.
# []
# []
# tensor([[0.9581, 0.0419],
#         [0.9570, 0.0430],
#         [0.9661, 0.0339],
#         [0.9606, 0.0394],
#         [0.9705, 0.0295],
#         [0.9544, 0.0456]], dtype=torch.float64)
#
# Atm in fuori servizio. Riscontrato ricircolatore banconote in errore, causa nastro precassa escrow fuori guida. Eseguito ripristino ricircolatore banconote con riposizionamento del nastro della precassa. Effettuato bonifica con aria compressa della parte superiore del dispensatore banconote. Verifica funzionamento atm con operazioni di prelievo e versamento banconote concluse tutte correttamente. Lasciato apparato in servizio regolare.
# ['NE ground-truth']
# ['NE ground-truth']
# tensor([[0.9542, 0.0458],
#         [0.9264, 0.0736],
#         [0.0944, 0.9056],
#         [0.9298, 0.0702],
#         [0.9501, 0.0499],
#         [0.9754, 0.0246]], dtype=torch.float64)
#
# Nessuna banconota ritrovata. Effettuata verifica al ricircolatore e taratura dei deviatori del trasporto banconote. Apparato ora regolarmente in servizio.
# []
# ['CT ground-truth']
# tensor([[0.8860, 0.1140],
#         [0.0798, 0.9202],
#         [0.9413, 0.0587],
#         [0.9208, 0.0792],
#         [0.9717, 0.0283],
#         [0.9727, 0.0273]], dtype=torch.float64)
#
# Guasto riscontrato: grg in errore hw 6117;
# Azione eseguita: sostituzione sfogliatore.
# Test in modalità utente ok.
# Non si riscontrano ulteriori anomalie.
# MTA ripristinato correttamente.
# ['NF ground-truth']
# ['NF ground-truth']
# tensor([[0.9584, 0.0416],
#         [0.9042, 0.0958],
#         [0.8959, 0.1041],
#         [0.0734, 0.9266],
#         [0.9549, 0.0451],
#         [0.9540, 0.0460]], dtype=torch.float64)
#
# Guasto riscontrato: ricircolatore molto sporco;
# Azione eseguita: pulizia approfondita e verifica periferiche cabinet con esito positivo.
# Eseguiti test di funzionamento ricircolatore grg con esito positivo.
# Non si riscontrano ulteriori anomalie.
#
# ['NF ground-truth', 'NV ground-truth']
# []
# tensor([[0.9186, 0.0814],
#         [0.9287, 0.0713],
#         [0.9270, 0.0730],
#         [0.5404, 0.4596],
#         [0.9689, 0.0311],
#         [0.9707, 0.0293]], dtype=torch.float64)
#
# Guasto riscontrato: inceppamento banconote in AC e parte upper;
# Azione eseguita: rimozione banconote inceppate.
# Eseguita pulizia e verifica GRG.
# Eseguiti test massivi a basso livello e prove in modalità utente con esito positivo.
# Non si riscontrano ulteriori anomalie.
# ['CT ground-truth']
# ['NE ground-truth']
# tensor([[0.9487, 0.0513],
#         [0.9216, 0.0784],
#         [0.1002, 0.8998],
#         [0.9207, 0.0793],
#         [0.9456, 0.0544],
#         [0.9777, 0.0223]], dtype=torch.float64)
#
# Guasto riscontrato: al mio arrivo, mta risulta correttamente operativo in seguito a rimozione dell'inceppamento da parte della filiale;
# Azione svolta: Eseguita verifica CT con analisi log e taratura diverter st01/st02. Eseguiti test massivi a basso livello con esito positivo.
# Non si riscontrano ulteriori anomalie. Apparato ripristinato correttamente.
# ['CT ground-truth']
# ['CT ground-truth']
# tensor([[0.8914, 0.1086],
#         [0.0954, 0.9046],
#         [0.8516, 0.1484],
#         [0.9244, 0.0756],
#         [0.9698, 0.0302],
#         [0.9743, 0.0257]], dtype=torch.float64)
#
# Guasto riscontrato: banconota L2 rinvenuta nel comparto A del cassetto AC;
# Azione eseguita: taratura diverter AC.
# Eseguiti test movimentazione diverter con esito positivo.
# Eseguita pulizia apparato e verifica lettore assegni su richiesta del personale di filiale.
# Non si riscontrano ulteriori anomalie.
# MTA ripristinato correttamente.
# ['NV ground-truth']
# ['CASSETTE ground-truth']
# tensor([[0.1774, 0.8226],
#         [0.6580, 0.3420],
#         [0.8658, 0.1342],
#         [0.9359, 0.0641],
#         [0.9701, 0.0299],
#         [0.9822, 0.0178]], dtype=torch.float64)
#
# Guasto riscontrato: inceppamento banconote su note feeder upper;
# Azione eseguita: rimozione inceppamento di una banconota da 20€ bloccata su feeder superiore.
# Eseguita verifica e pulizia feeder.
# Eseguiti test massivi di funzionamento con esito positivo.
# Non si riscontrano ulteriori anomalie.
# MTA ripristinato correttamente.
# ['NF ground-truth']
# ['NF ground-truth']
# tensor([[0.9591, 0.0409],
#         [0.9008, 0.0992],
#         [0.8638, 0.1362],
#         [0.0759, 0.9241],
#         [0.9582, 0.0418],
#         [0.9549, 0.0451]], dtype=torch.float64)
#
# Guasto riscontrato: errore durante movimentazione diverter nf inferiore;
# Azione eseguita: verifica dispensatore. Rinvenuta e rimossa graffetta mettallica all'interno del link transport.
# Eseguiti test massivi a basso livello con esito positivo.
# Test modalità utente con esito positivo.
# Mta ripristinato correttamente.
#
# ['NF ground-truth']
# ['CT ground-truth', 'NF ground-truth']
# tensor([[0.9235, 0.0765],
#         [0.2715, 0.7285],
#         [0.8570, 0.1430],
#         [0.2191, 0.7809],
#         [0.9688, 0.0312],
#         [0.9677, 0.0323]], dtype=torch.float64)
#
# Guasto riscontrato: anomalia 9305 (inceopamento nf);
# Azione eseguita: non è stato riscontrato nessun inceppamento, risulta falso positivo causato da cablaggio danneggiato.
# Ripristinato cablaggio parte superiore dispensatore.
# Eseguiti test di funzionamento con esito positivo.
# Non si riscontrano ulteriori anomalie.
# ['NE ground-truth']
# ['NF ground-truth']
# tensor([[0.9429, 0.0571],
#         [0.9267, 0.0733],
#         [0.9193, 0.0807],
#         [0.0821, 0.9179],
#         [0.9541, 0.0459],
#         [0.9540, 0.0460]], dtype=torch.float64)
#
# Guasto riscontrato: gommini interni note escrow sciolti;
# Azione eseguita: sostituzione note escrow.
# Eseguiti test massivi con esito positivo.
# Non si riscontrano ulteriori anomalie.
# Mta ripristinato correttamente.
#
# ['NE ground-truth']
# ['NE ground-truth']
# tensor([[0.9556, 0.0444],
#         [0.9264, 0.0736],
#         [0.0935, 0.9065],
#         [0.9228, 0.0772],
#         [0.9505, 0.0495],
#         [0.9752, 0.0248]], dtype=torch.float64)
#
# Guasto riscontrato: cinghia cash transport spezzata;
# Azione eseguita: sostituzione cash transport.
# Eseguiti test massivi a basso livello con esito positivo.
# Test in modalità utente ok.
# Non si riscontrano ulteriori anomalie.
# ['CT ground-truth']
# ['CT ground-truth']
# tensor([[0.9017, 0.0983],
#         [0.0758, 0.9242],
#         [0.9135, 0.0865],
#         [0.9220, 0.0780],
#         [0.9719, 0.0281],
#         [0.9732, 0.0268]], dtype=torch.float64)
#
# ATM trovato fuori servizio, la filiale mi ha specificato che hanno eseguito un versamento con graffetta, motivo dei recenti inceppamenti e degli scarti riscontrati, eseguite diverse prove con esito positivo, ATM in regolare funzionamento.
# ['CASSETTE ground-truth']
# []
# tensor([[0.9571, 0.0429],
#         [0.9568, 0.0432],
#         [0.8227, 0.1773],
#         [0.8938, 0.1062],
#         [0.9696, 0.0304],
#         [0.9573, 0.0427]], dtype=torch.float64)
#
# Guasto riscontrato Nastro dell escrow attorciglia a seguito di rimozione banconote a mano dalla precassa dopo aver spiegato la giusta procedura per rimuovere le banconote. Eseguito riposizionamento nastro escrow con successive prove di funzionamento andate a buon fine. Macchina lasciata in servizio.
# ['NE ground-truth']
# ['NE ground-truth']
# tensor([[0.9566, 0.0434],
#         [0.9215, 0.0785],
#         [0.0929, 0.9071],
#         [0.9202, 0.0798],
#         [0.9504, 0.0496],
#         [0.9745, 0.0255]], dtype=torch.float64)
#
# GR banconota da 50€ inceppata su Cash transport, eseguita rimozione corpo estraneo più sostituito cassetto da 50€ per piatto rotto. Eseguite prove di accettazione e dispensazione banconote andate a buon fine.
# ['CASSETTE ground-truth', 'CT ground-truth', 'NV ground-truth']
# ['CASSETTE ground-truth', 'CT ground-truth']
# tensor([[0.3155, 0.6845],
#         [0.2391, 0.7609],
#         [0.9153, 0.0847],
#         [0.9249, 0.0751],
#         [0.9768, 0.0232],
#         [0.9791, 0.0209]], dtype=torch.float64)
#
# MTA FS.
# Effettuato controllo dispensatore, rinvenuta moneta da 2 euro in zona NF.
# effettuate prove di funzionamento con clienti intesa san paolo.
# ['NF ground-truth']
# ['NF ground-truth']
# tensor([[0.9635, 0.0365],
#         [0.9193, 0.0807],
#         [0.9234, 0.0766],
#         [0.0725, 0.9275],
#         [0.9604, 0.0396],
#         [0.9502, 0.0498]], dtype=torch.float64)
#
# Intervento anticipato.
# MTA FS.
# Effettuato controllo inceppamenti,  riscontrate bnc versate in maniera errata (in verticale).
# Rimosse ed eseguito controllo cassetti, riscontrane bnc da 50 non smazzettate.
# Prove di funzionamento ok.
# ['NF ground-truth']
# []
# tensor([[0.9524, 0.0476],
#         [0.9742, 0.0258],
#         [0.8763, 0.1237],
#         [0.9414, 0.0586],
#         [0.9678, 0.0322],
#         [0.9614, 0.0386]], dtype=torch.float64)
#
# Mta FS.
# Rinvenute bnc strappate in zona NE.
# Rimosse ed effettuate prove tramite tool con esito positivo.
# Funzionalità ripristinate.
# ['NE ground-truth']
# ['NE ground-truth']
# tensor([[0.9547, 0.0453],
#         [0.9550, 0.0450],
#         [0.2506, 0.7494],
#         [0.9521, 0.0479],
#         [0.9554, 0.0446],
#         [0.9763, 0.0237]], dtype=torch.float64)
#
# Mta fs.
# Effettuato controllo inceppamenti,  rinvenuta monetina in zona NF INFERIORE, rimosse bnc inceppate ed effettuate prove di funzionamento con tool con esito positivo.
# ['NF ground-truth']
# ['NF ground-truth']
# tensor([[0.9644, 0.0356],
#         [0.9168, 0.0832],
#         [0.9037, 0.0963],
#         [0.0720, 0.9280],
#         [0.9579, 0.0421],
#         [0.9532, 0.0468]], dtype=torch.float64)
#
# Mta fs.
# Effettuato controllo visivo, riscontrate cinghie escrow fuori sede.
# Rimesse in posizione ed effettuate prove con clienti intesa san paolo.
# Funzionalità ripristinate.
# ['NE ground-truth']
# ['NE ground-truth']
# tensor([[0.9589, 0.0411],
#         [0.9242, 0.0758],
#         [0.0926, 0.9074],
#         [0.9199, 0.0801],
#         [0.9514, 0.0486],
#         [0.9747, 0.0253]], dtype=torch.float64)
#
# Ricircolatore trovato con leva 10 aperta. Rimossa banconota da 20 euro inceppata nel Escrow. Ricircolatore pulito e ispezionato senza riscontrare anomalie hardware. ATM rimesso in funzione e testato correttamente.
# ['CT ground-truth']
# ['NE ground-truth']
# tensor([[0.9492, 0.0508],
#         [0.9192, 0.0808],
#         [0.1032, 0.8968],
#         [0.9072, 0.0928],
#         [0.9485, 0.0515],
#         [0.9761, 0.0239]], dtype=torch.float64)
#
# GR dispensatore ko
# Riposizionato correttamente cinghie escrow dopo aver rimosso corpo estraneo da dispensatore
# Effettuato con successo prove di dispensazione e di versamento
# ['NE ground-truth']
# ['NE ground-truth']
# tensor([[0.9560, 0.0440],
#         [0.9255, 0.0745],
#         [0.0941, 0.9059],
#         [0.9269, 0.0731],
#         [0.9458, 0.0542],
#         [0.9748, 0.0252]], dtype=torch.float64)
#
# Effettuata pulizia ed analisi log. Data assistenza alla filiale nella quadratura e sostituito il cassetto AC guasto. Effettuate prove e rimesso in servizio l'apparato.
# ['CASSETTE ground-truth']
# ['CASSETTE ground-truth']
# tensor([[0.1192, 0.8808],
#         [0.9350, 0.0650],
#         [0.9645, 0.0355],
#         [0.9613, 0.0387],
#         [0.9662, 0.0338],
#         [0.9746, 0.0254]], dtype=torch.float64)
#
# ATM trovato fuori servizio, trovato errore su solenoide cassetto rc2, eseguite diverse prove di movimentazioni senza trovare anomalie, eseguite prove di prelievo e versamento con esito positivo, ATM in regolare funzionamento.
# ['CT ground-truth']
# ['CASSETTE ground-truth']
# tensor([[0.1204, 0.8796],
#         [0.9321, 0.0679],
#         [0.9608, 0.0392],
#         [0.9534, 0.0466],
#         [0.9676, 0.0324],
#         [0.9756, 0.0244]], dtype=torch.float64)
#
# Rimosso inceppamento NE ed eseguita pulizia dispensatore. Test ok. ATM in servizio
# ['NE ground-truth']
# ['NE ground-truth']
# tensor([[0.9615, 0.0385],
#         [0.9312, 0.0688],
#         [0.0984, 0.9016],
#         [0.9315, 0.0685],
#         [0.9525, 0.0475],
#         [0.9761, 0.0239]], dtype=torch.float64)
#
# Eseguita pulizia validatore e dispensatore perché generava molti scarti. Eseguito controllo banconota mancante senza ritrovarne alcuna. Test ok. ATM in servizio
# ['NV ground-truth']
# ['NV ground-truth']
# tensor([[0.9663, 0.0337],
#         [0.9727, 0.0273],
#         [0.9557, 0.0443],
#         [0.9566, 0.0434],
#         [0.1550, 0.8450],
#         [0.9686, 0.0314]], dtype=torch.float64)
#
# GR: trovato sfogliatore inferiore con cinghia spezzata.
# Sostituzione sfogliatore, verifica cassetti e pulizia gommini cassetti, reset apparato e prove di accettazione e dispensazione con tool.
# ['NF ground-truth']
# ['NF ground-truth']
# tensor([[0.9478, 0.0522],
#         [0.9065, 0.0935],
#         [0.9225, 0.0775],
#         [0.0751, 0.9249],
#         [0.9622, 0.0378],
#         [0.9526, 0.0474]], dtype=torch.float64)
#
# Apparato in funzione con servizio banconote in blocco a causa di una banconota incastrata nello sfogliatiore inferiore. Rimosso l'inceppamento, test funzionali con esito positivo.
# ['NF ground-truth']
# ['NF ground-truth']
# tensor([[0.9596, 0.0404],
#         [0.9050, 0.0950],
#         [0.9105, 0.0895],
#         [0.0728, 0.9272],
#         [0.9553, 0.0447],
#         [0.9534, 0.0466]], dtype=torch.float64)
#
# Eseguito controllo e taratura validatore con esito positivo. Apparato in regolare servizio
# ['NV ground-truth']
# ['NV ground-truth']
# tensor([[0.9658, 0.0342],
#         [0.9715, 0.0285],
#         [0.9537, 0.0463],
#         [0.9582, 0.0418],
#         [0.1563, 0.8437],
#         [0.9677, 0.0323]], dtype=torch.float64)
#
# Rimossa banconota da 20 euro inceppata nel cash transport. Ispezionato il ricircolatore e pulito senza rilevare anomalie hardware. ATM rimesso in funzione e testato correttamente.
# Rimosso inoltre inceppamento di banconote accartocciate nel cassetto da 20 del ATM 7848. ATM rimesso in funzione e testato correttamente.
# ['CT ground-truth']
# ['CT ground-truth']
# tensor([[0.8582, 0.1418],
#         [0.0786, 0.9214],
#         [0.9098, 0.0902],
#         [0.9252, 0.0748],
#         [0.9738, 0.0262],
#         [0.9745, 0.0255]], dtype=torch.float64)
#
# Guasto riscontrato: banconote inceppate nel trasporto e nella precassp escrow
# Lavoro eseguito: rimosse banconote inceppate,  sostituito cassetto rc1 (20 euro). Verificato funzionamento in modalità utente con esito positivo
# ['CT ground-truth']
# ['CT ground-truth', 'NE ground-truth']
# tensor([[0.5826, 0.4174],
#         [0.3699, 0.6301],
#         [0.3575, 0.6425],
#         [0.9099, 0.0901],
#         [0.9697, 0.0303],
#         [0.9825, 0.0175]], dtype=torch.float64)
#
# Guasto riscontrato: banconote inceppate nel note validator e corpo estraneo presente nel dispensatore
# Lavoro eseguito: rimosse banconote inceppate,  effettuata pulizia dispensatore.  Verificato funzionamento in modalità utente con esito positivo
# ['NE ground-truth']
# ['NV ground-truth']
# tensor([[0.9635, 0.0365],
#         [0.9619, 0.0381],
#         [0.7297, 0.2703],
#         [0.9348, 0.0652],
#         [0.2214, 0.7786],
#         [0.9735, 0.0265]], dtype=torch.float64)
#
# Dispesatore inceppa all'ingresso dei cassetti. Rilevato trasporto non funzionante. Sostituito trasporto regolato e rimesso in servizio eseguito prove di funzionamento con esito positivo
# ['CT ground-truth']
# ['CT ground-truth']
# tensor([[0.8474, 0.1526],
#         [0.0823, 0.9177],
#         [0.9329, 0.0671],
#         [0.9232, 0.0768],
#         [0.9763, 0.0237],
#         [0.9730, 0.0270]], dtype=torch.float64)
#
# G.R.apparato funzionante eseguita ispezione dell mta in tutte le sue parti , non vi risultano banconote in nessuna parte. Sostituito lettore assegni.
# []
# []
# tensor([[0.9753, 0.0247],
#         [0.9281, 0.0719],
#         [0.9676, 0.0324],
#         [0.9541, 0.0459],
#         [0.9643, 0.0357],
#         [0.9643, 0.0357]], dtype=torch.float64)
#
# G.R. dispensatore banconote fuori servizio rimossa parte di una banconota da 20€ inceppata nel cashtrasport, eseguiti controlli e test finali con esito positivo macchina nuovamente funzionante.
# ['CT ground-truth']
# ['CT ground-truth']
# tensor([[0.8744, 0.1256],
#         [0.0893, 0.9107],
#         [0.9309, 0.0691],
#         [0.9243, 0.0757],
#         [0.9601, 0.0399],
#         [0.9777, 0.0223]], dtype=torch.float64)
#
# Anomalia dispensazione.
# Riscontrato ATM fuori servizio causa Anomalia 950a.
# Causa versamento errato con corpo estraneo.
# Rimosso inceppamento corpo  estraneo e eseguita pulizia dispensatore.
# Eseguiti I test di funzionamento e accettazione e dispensazione Banconote con esito positivo.
# Guasto rientrato.
# ATM in servizio.
# ['CT ground-truth']
# ['NE ground-truth']
# tensor([[0.9557, 0.0443],
#         [0.9346, 0.0654],
#         [0.3167, 0.6833],
#         [0.9450, 0.0550],
#         [0.9415, 0.0585],
#         [0.9718, 0.0282]], dtype=torch.float64)
#
# Guasto riscontrato graffetta inserita con le banconote eseguì per rimozione e test ATM ok
# ['CT ground-truth']
# ['NE ground-truth']
# tensor([[0.9640, 0.0360],
#         [0.9417, 0.0583],
#         [0.2958, 0.7042],
#         [0.9277, 0.0723],
#         [0.9545, 0.0455],
#         [0.9712, 0.0288]], dtype=torch.float64)
#
# Guasto riscontrato dispensatore non rilevato dal PC. Eseguito reset elettrico eseguita analisi log con supporto tecnico. Eseguita sostituzione lower plate AC b, feeder sup. e scheda upper. Eseguiti test. Atm ok
# ['CT ground-truth', 'NF ground-truth']
# ['CT ground-truth', 'NF ground-truth']
# tensor([[0.9273, 0.0727],
#         [0.2963, 0.7037],
#         [0.8915, 0.1085],
#         [0.2116, 0.7884],
#         [0.9683, 0.0317],
#         [0.9643, 0.0357]], dtype=torch.float64)
#
# Guasto riscontrato cover connettore cassetto rotto, eseguita sostituzione e test. Atm ok
# ['CASSETTE ground-truth']
# ['CASSETTE ground-truth']
# tensor([[0.1224, 0.8776],
#         [0.9367, 0.0633],
#         [0.9634, 0.0366],
#         [0.9581, 0.0419],
#         [0.9687, 0.0313],
#         [0.9747, 0.0253]], dtype=torch.float64)
#
# Pulizia generale gruppo grg con compressore. Sostituzione e configurazione cassetto rc 20 euro + riposizionamento piatto cassetto rc 50 euro. Reset lettore assegni. Test dispensazione/accettazione contanti con esito positivo. Restart apparato e collaudo ok.
# ['CASSETTE ground-truth']
# ['CASSETTE ground-truth']
# tensor([[0.1176, 0.8824],
#         [0.9273, 0.0727],
#         [0.9564, 0.0436],
#         [0.9581, 0.0419],
#         [0.9667, 0.0333],
#         [0.9777, 0.0223]], dtype=torch.float64)
#
# G. R. Rilevato sfogliatore inferiore con cinghia guasta, eseguito quindi sostituzione. Al primo reset dispensatore ritorna in errore per colpa della scheda upper la quale non comunica più con nessun sensore della parte superiore. Eseguito sostituzione anche della scheda con esito positivo. Eseguito quindi collaudo con banconote reali con esito positivo. Apparato in regolare servizio utente.
# ['NF ground-truth']
# ['NF ground-truth']
# tensor([[0.9586, 0.0414],
#         [0.9056, 0.0944],
#         [0.9156, 0.0844],
#         [0.0728, 0.9272],
#         [0.9559, 0.0441],
#         [0.9528, 0.0472]], dtype=torch.float64)
#
# Trovato atm con dispensatore fuori servizio, analisi log e rilevato problema su cash trasport. Rilevati piatti e denti trasporto rotti. Sostituzione trasporto. Prove massicce di funzionamento ok. Prove di prelievo e versamento ok.
# ['CT ground-truth']
# ['CT ground-truth']
# tensor([[0.8833, 0.1167],
#         [0.0776, 0.9224],
#         [0.9299, 0.0701],
#         [0.9257, 0.0743],
#         [0.9732, 0.0268],
#         [0.9730, 0.0270]], dtype=torch.float64)
#
# Dispensatore/Accettatore banconote Off-Line.
# Guasto riscontrato: FS 3105.
# Riscontrato corpo estraneo in NV/NE.
# Lavoro eseguito: effettuata rimozione corpo estraneo.
# Effettuata pulizia Ricircolatore Banconote.
# Verificata corretta operatività periferica attraverso transazioni in modalità utente con riscontro positivo.
# ['NE ground-truth']
# ['NV ground-truth']
# tensor([[0.9599, 0.0401],
#         [0.9700, 0.0300],
#         [0.8935, 0.1065],
#         [0.9413, 0.0587],
#         [0.1956, 0.8044],
#         [0.9710, 0.0290]], dtype=torch.float64)
#
# Sul posto rilevo ATM Parzialmente in servizio con ricircolatore in anomalia causa inceppamento su sfogliatore inferiore.
# Rimosse 2 banconote da 50€ e restituite al cassiere.
# Revisionato sfogliatore inferiore ed eseguite prove di funzionamento con esito positivo.
# ATM in servizio.
# ['NF ground-truth']
# ['NF ground-truth']
# tensor([[0.9597, 0.0403],
#         [0.9021, 0.0979],
#         [0.9005, 0.0995],
#         [0.0730, 0.9270],
#         [0.9567, 0.0433],
#         [0.9531, 0.0469]], dtype=torch.float64)
#
# Sul posto rilievo ATM fuori servizio per quadratura del cassiere.
# La filiale mi comunica che il bancomat non ha fino ad ora ricircolato banconote macchiate.
# Eseguita comunque pulizia e calibrazione del validatore.
# Atm lasciato in fase di quadratura da parte del cassiere.
# ['NV ground-truth']
# ['NV ground-truth']
# tensor([[0.9650, 0.0350],
#         [0.9696, 0.0304],
#         [0.9522, 0.0478],
#         [0.9588, 0.0412],
#         [0.1572, 0.8428],
#         [0.9671, 0.0329]], dtype=torch.float64)
#
# Sul posto rilevo ATM correttamente in servizio.
# Dopo verifiche rilevo NV problematico.
# Eseguita revisione completa del validatore ed effettuato verifiche di funzionamento con esito positivo.
# ATM in servizio.
# ['NV ground-truth']
# ['NV ground-truth']
# tensor([[0.9655, 0.0345],
#         [0.9707, 0.0293],
#         [0.9555, 0.0445],
#         [0.9596, 0.0404],
#         [0.1558, 0.8442],
#         [0.9667, 0.0333]], dtype=torch.float64)
#
# ATM in regolare servizio. Filiale segnala piatto nt-r superiore staccato, effetuata sostituzione della parte, eseguite prove lato clientela in quanto cassaforte era in blocco. Prove sia di versamento che di prelievo con esito positivo. ATM in regolare servizio
# ['NF ground-truth']
# []
# tensor([[0.9585, 0.0415],
#         [0.9363, 0.0637],
#         [0.8303, 0.1697],
#         [0.8574, 0.1426],
#         [0.9388, 0.0612],
#         [0.9679, 0.0321]], dtype=torch.float64)
#
# ATM fuori servizio. Banconota da 20 nello sfogliatore superiore, rimossa, dovuto a un versamento non andato a buon fine. Eseguito controllo totale dispensatore senza riscontrare problematiche, prove da tool massive con esito positivo. Prove con atm in servizio con esito positivo. Possibili problemi sul prelievo delle banconote da 20 in quanto risultano essercene una 30ina circa, si richiede carico.
# ['NF ground-truth']
# ['NF ground-truth']
# tensor([[0.9594, 0.0406],
#         [0.8992, 0.1008],
#         [0.8781, 0.1219],
#         [0.0745, 0.9255],
#         [0.9537, 0.0463],
#         [0.9557, 0.0443]], dtype=torch.float64)
#
#
# Al mio arrivo l'atm risultava parzialmente funzionante
# Riscontravo fuoriuscita nastro escrow
# Procedevo al recupero del nastro.
# Verifica funzionamento atm ok
# Rimessa in servizio.
#
# ['NE ground-truth']
# ['NE ground-truth']
# tensor([[0.9570, 0.0430],
#         [0.9253, 0.0747],
#         [0.0935, 0.9065],
#         [0.9226, 0.0774],
#         [0.9483, 0.0517],
#         [0.9749, 0.0251]], dtype=torch.float64)
#
# Al mio arrivo l'atm risultava parzialmente funzionante
# Riscontravo banconote inceppate all'interno del nastro escrow
# Procedevo al recupero delle banconote e alla sostituzione dell' escrow e scheda upper.
# Verifica funzionamento atm ok
# Rimessa in servizio.
#
# ['NE ground-truth']
# ['NE ground-truth']
# tensor([[0.9552, 0.0448],
#         [0.9254, 0.0746],
#         [0.0942, 0.9058],
#         [0.9249, 0.0751],
#         [0.9505, 0.0495],
#         [0.9754, 0.0246]], dtype=torch.float64)
#
# Arrivato in filiale ATM fuori servizio con errore 9517
# Effettuato controllo e riscontrato problema sul ct e sul validatore che ho sostituito
# Rimesso in servizio la macchina ed effettuato test di corretto funzionamento con esito OK
# ATM in regolare servizio
# ['CT ground-truth', 'NV ground-truth']
# ['CT ground-truth', 'NV ground-truth']
# tensor([[0.9374, 0.0626],
#         [0.4957, 0.5043],
#         [0.9287, 0.0713],
#         [0.9489, 0.0511],
#         [0.4423, 0.5577],
#         [0.9665, 0.0335]], dtype=torch.float64)
#
# Arrivato in filiale ATM fuori servizio con anomalia 2031
# Effettuato controllo e riscontrato cinghie inferiori precassa fuori posizione che ho riposizionato
# Rimesso in servizio la macchina
# Test di corretto funzionamento con esito OK
# ATM in regolare servizio
# ['NE ground-truth']
# []
# tensor([[0.9700, 0.0300],
#         [0.9209, 0.0791],
#         [0.6241, 0.3759],
#         [0.7451, 0.2549],
#         [0.9624, 0.0376],
#         [0.9556, 0.0444]], dtype=torch.float64)
#
# Arrivato in filiale ATM fuori servizio con anomalia sul dispensatore
# Effettuato controllo e riscontrato cassetto da 50 euro malfunzionante
# Provveduto quindi alla sostituzione del cassetto.
# Rimosso corpo estraneo.
# Rimesso in servizio la macchina ed effettuato test di corretto funzionamento con esito OK
# ATM in regolare servizio
# ['CT ground-truth']
# ['CASSETTE ground-truth']
# tensor([[0.1187, 0.8813],
#         [0.9285, 0.0715],
#         [0.9559, 0.0441],
#         [0.9579, 0.0421],
#         [0.9675, 0.0325],
#         [0.9768, 0.0232]], dtype=torch.float64)
#
# Riscontrato atm con prelievo e versamento fuori servizio e codice d'errore 950a. Si riscontrano le cinghie fuoriuscite, nel riposizionarle, si riscontra anche il nastro inceppato, ma il tentativo di ripristinarlo non va a buon fine e quindi sostituzione dell'escrow. Test di dispensazione e deposito positivi. Rimessa in servizio dell'atm e prove positive.
# ['NE ground-truth']
# ['NE ground-truth']
# tensor([[0.9563, 0.0437],
#         [0.9204, 0.0796],
#         [0.0934, 0.9066],
#         [0.9137, 0.0863],
#         [0.9444, 0.0556],
#         [0.9749, 0.0251]], dtype=torch.float64)
#
# Eseguita rimozione del pezzo di banconota mancante dal CT, pulizia dello stesso e prove funzionali con successo
# ['CT ground-truth']
# ['CT ground-truth']
# tensor([[0.9061, 0.0939],
#         [0.0755, 0.9245],
#         [0.8906, 0.1094],
#         [0.9120, 0.0880],
#         [0.9733, 0.0267],
#         [0.9731, 0.0269]], dtype=torch.float64)
#
# Gr anomalia da applicativo su cassetti versamento, eseguito reset pc anomalia scomparsa,  analisi log nessuna anomalia riscontrata
# []
# []
# tensor([[0.7003, 0.2997],
#         [0.9585, 0.0415],
#         [0.9623, 0.0377],
#         [0.9790, 0.0210],
#         [0.9730, 0.0270],
#         [0.9666, 0.0334]], dtype=torch.float64)
#
# G.r. banconote logora inceppata su note feeder superiore. Rimosso inceppamento da note feeder superiore. Test di dispensazione e versamento banconote con esito positivo.
# ['NF ground-truth']
# ['NF ground-truth']
# tensor([[0.9607, 0.0393],
#         [0.9094, 0.0906],
#         [0.9258, 0.0742],
#         [0.0738, 0.9262],
#         [0.9530, 0.0470],
#         [0.9533, 0.0467]], dtype=torch.float64)
#
# Nessuna anomalia riscontrata. Controllato log ed effettuato test
# []
# []
# tensor([[0.9659, 0.0341],
#         [0.9674, 0.0326],
#         [0.9252, 0.0748],
#         [0.9808, 0.0192],
#         [0.9551, 0.0449],
#         [0.9627, 0.0373]], dtype=torch.float64)
#
# Riparato cassetto da 50 euro a causa di cinghia del piatto uscita dalla sede e ripristinato sensore di fine corsa del piatto.
# Effettuate prove di funzionamento con esito positivo.
# ['CASSETTE ground-truth']
# ['CASSETTE ground-truth']
# tensor([[0.1184, 0.8816],
#         [0.9347, 0.0653],
#         [0.9677, 0.0323],
#         [0.9635, 0.0365],
#         [0.9677, 0.0323],
#         [0.9755, 0.0245]], dtype=torch.float64)
#
# Atm in fuori servizio. Riscontrato ricircolatore banconote in errore con nastro della precassa escrow fuori guida, causa versamento banconote con corpo estraneo. Eseguito ripristino del ricircolatore banconote con riposizionamento del nastro della precassa, rimozione delle banconote inceppate e corpo estraneo. Effettuato bonifica del dispensatore banconote. Verifica funzionamento atm con operazioni di prelievo e versamento banconote concluse tutte correttamente. Lasciato apparato in servizio regolare.
# ['NE ground-truth']
# ['NE ground-truth']
# tensor([[0.9521, 0.0479],
#         [0.9254, 0.0746],
#         [0.0954, 0.9046],
#         [0.9232, 0.0768],
#         [0.9483, 0.0517],
#         [0.9758, 0.0242]], dtype=torch.float64)
#
# Mta trovato in fuoriservizio. Intervento effettuato con la presenza del personale di filiale. Dopo analisi con il supporto tecnico che a sua volta si è interfacciato con Intesa, si è reso necessario rifare una prima installazione ed il carico delle quantità fornite dal presidio Intesa. Test positivo. Effettuato riconfigurazione del note validator. Test positivo. Monitor esterno guasto. Effettuato sostituzione e configurazione. Test positivo. Riavviato mta. Test di funzionamento positive
# Mta in servizio.
# []
# ['NV ground-truth']
# tensor([[0.9636, 0.0364],
#         [0.9679, 0.0321],
#         [0.9484, 0.0516],
#         [0.9513, 0.0487],
#         [0.1586, 0.8414],
#         [0.9680, 0.0320]], dtype=torch.float64)
#
# Troppi l2
# Soluzione
# Sostituito validatore e collaudato con esito positivo. Rimessa in servizio utente
# ['NV ground-truth']
# ['NV ground-truth']
# tensor([[0.9663, 0.0337],
#         [0.9698, 0.0302],
#         [0.9536, 0.0464],
#         [0.9548, 0.0452],
#         [0.1571, 0.8429],
#         [0.9675, 0.0325]], dtype=torch.float64)
#
# Riscontro errore 950b, leva 10 aperta e moneta da 2 euro in area feeder. Rimossa moneta, riposizionata la leva. Scarico e analisi log. Test dispensazioni e versamenti con tool ok. Pulizia. Attesa quadratura. MTA in servizio.
# ['NF ground-truth']
# ['NF ground-truth']
# tensor([[0.9643, 0.0357],
#         [0.9168, 0.0832],
#         [0.9180, 0.0820],
#         [0.0731, 0.9269],
#         [0.9568, 0.0432],
#         [0.9518, 0.0482]], dtype=torch.float64)
#
# Rilevato magnete deviatore sfogliatore inferiore malfunzionante.
# Eseguita sostituzione magnete deviatore sfogliatore inferiore.
# Esegue prove di erogazione e deposito banconote con esito regolare.
# ['NF ground-truth']
# ['NF ground-truth']
# tensor([[0.9560, 0.0440],
#         [0.8863, 0.1137],
#         [0.9063, 0.0937],
#         [0.0763, 0.9237],
#         [0.9536, 0.0464],
#         [0.9538, 0.0462]], dtype=torch.float64)
#
# Rilevate cinghie dello sfogliatore inferiore tutte usurate, cassetto rc da 50 euro malfunzionante e note validator con sensori starati.
# Eseguita sostituzione sfogliatore inferiore, eseguita sostituzione e configurazione cassetto rc da 50 euro. Eseguita pulizie superiore ed inferiore e taratura note validator.
# Verifica corretto funzionamento con esito regolare.
# ['CASSETTE ground-truth', 'NF ground-truth', 'NV ground-truth']
# ['NF ground-truth']
# tensor([[0.7474, 0.2526],
#         [0.9263, 0.0737],
#         [0.9250, 0.0750],
#         [0.3399, 0.6601],
#         [0.6927, 0.3073],
#         [0.9706, 0.0294]], dtype=torch.float64)
#
# Guasto riscontrato: dispensatore offline causa cassetto DC FIT guasto.
# Intervento eseguito: sostituito e configurato cassetto FIT con esito positivo.
# Test dispensatore con esito positivo.
# Prove funzionamento in modalità utente esito positivo.
# ['CASSETTE ground-truth']
# ['CASSETTE ground-truth']
# tensor([[0.1261, 0.8739],
#         [0.9158, 0.0842],
#         [0.9291, 0.0709],
#         [0.9532, 0.0468],
#         [0.9615, 0.0385],
#         [0.9806, 0.0194]], dtype=torch.float64)
#
# Al mio arrivo rilevo mta con grg in an 8021.
# Nel cassetto da 20 euro rilevato sensore a forchetta danneggiato irrimediabilmente e piatto pressa banconote tutto storto. Eseguita operazione di raddrizzamento del piatto pressa banconote ed eseguita sostituzione sensore a forchetta.
# Verifica corretto funzionamento con esito regolare.
# Prova di prelievo contanti con esito regolare.
# ['CASSETTE ground-truth']
# []
# tensor([[0.8065, 0.1935],
#         [0.9420, 0.0580],
#         [0.9160, 0.0840],
#         [0.9381, 0.0619],
#         [0.9552, 0.0448],
#         [0.9726, 0.0274]], dtype=torch.float64)
#
# Sostituzione precassa escrow
#
# ['NE ground-truth']
# ['NE ground-truth']
# tensor([[0.9535, 0.0465],
#         [0.9248, 0.0752],
#         [0.0957, 0.9043],
#         [0.9271, 0.0729],
#         [0.9420, 0.0580],
# ...
#         [0.9668, 0.0332]], dtype=torch.float64)
#
# Al momento dell'intervento l'apparato è in regolare funzionamento e servizio, autonomamente ha risolto l'inceppamento banconote, rimesso in servizio verifiche finali funzionamento Mta.
# ['CT ground-truth']
# []
# tensor([[0.9711, 0.0289],
#         [0.9457, 0.0543],
#         [0.7091, 0.2909],
#         [0.9103, 0.0897],
#         [0.9638, 0.0362],
#         [0.9629, 0.0371]], dtype=torch.float64)
#
# Rimozione n. 3 banconote da 20€ incastrate tra il Cassetto e  il Cash transport in fase di prelievo, controllo e pulizia generale, riavvio apparato per ripristino Cassetto in quanto disattivato dell'applicativo e verifiche finali funzionamento Mta con clienti Intesa SanPaolo.
# ['CASSETTE ground-truth']
# ['CASSETTE ground-truth', 'CT ground-truth']
# tensor([[0.2919, 0.7081],
#         [0.2600, 0.7400],
#         [0.9300, 0.0700],
#         [0.9283, 0.0717],
#         [0.9772, 0.0228],
#         [0.9792, 0.0208]], dtype=torch.float64)
#
# Carico non conforme sono state caricate le banconote da 20 nel cassetto da 50 e le banconote da 50 nei 20, atm rientrato in servizio dopo il riposizionamento delle banconote nei relativi cassetti. Prove di prelievo e versamento con esito positivo.
# []
# []
# tensor([[0.8995, 0.1005],
#         [0.9567, 0.0433],
#         [0.9081, 0.0919],
#         [0.9538, 0.0462],
#         [0.9563, 0.0437],
#         [0.9635, 0.0365]], dtype=torch.float64)
#
# Rimosse banconote incastrate all ingresso dell NE delle bnc provenienti dal NV riposizionamento delle cinghie dell NE, Rimosse banconote dal rullo dell NE. Atm di nuovo in servizio con prove di prelievo e versamento con esito positivo.
# ['NE ground-truth']
# ['NV ground-truth']
# tensor([[0.9662, 0.0338],
#         [0.9648, 0.0352],
#         [0.6552, 0.3448],
#         [0.9564, 0.0436],
#         [0.2442, 0.7558],
#         [0.9753, 0.0247]], dtype=torch.float64)
#
# G.r. a volte scarta banconote in fase di versamento. Eseguito pulizia ricircolatore. Sostituzione alimentatore PC in quanto durante l'intervento ha creato un corto circuito. Test di dispensatore e versamento da diagnostico con esito positivo. Test di dispensazione e versamento da applicativo cliente con esito positivo.
# Apparato in regolare servizio utente.
# ['NF ground-truth']
# ['NF ground-truth']
# tensor([[0.9559, 0.0441],
#         [0.8936, 0.1064],
#         [0.7797, 0.2203],
#         [0.3990, 0.6010],
#         [0.9109, 0.0891],
#         [0.9756, 0.0244]], dtype=torch.float64)
#
# Riscontrato shutter schiuso, non risultano manomissioni. Eseguita pulizia interna e prove di funzionamento con esito regolare. Contattato presidio per la rimessa in servizio dell'apparato.
# ['SHUTTER ground-truth']
# ['SHUTTER ground-truth']
# tensor([[0.9737, 0.0263],
#         [0.9681, 0.0319],
#         [0.9736, 0.0264],
#         [0.9542, 0.0458],
#         [0.9657, 0.0343],
#         [0.2068, 0.7932]], dtype=torch.float64)
#
# Sostituita precassa e trasporto banconote ed effettuate prove di funzionamento.
# ['CT ground-truth', 'NE ground-truth']
# ['CT ground-truth']
# tensor([[0.9095, 0.0905],
#         [0.0774, 0.9226],
#         [0.9324, 0.0676],
#         [0.9151, 0.0849],
#         [0.9726, 0.0274],
#         [0.9710, 0.0290]], dtype=torch.float64)
#
# Atm in fuori servizio. Riscontrato ricircolatore banconote in errore, causa scheda lower unit, scheda upper unit e cablaggio parte superiore guasti. Effettuato ripristino ricircolatore banconote con la sostituzione delle schede e del cablaggio. Sostituito, inoltre, monitor esterno non correttamente funzionante. Verifica funzionamento atm con operazioni di prelievo e versamento banconote concluse tutte correttamente. Lasciato apparato in servizio regolare.
# []
# []
# tensor([[0.9600, 0.0400],
#         [0.9505, 0.0495],
#         [0.9681, 0.0319],
#         [0.9236, 0.0764],
#         [0.9674, 0.0326],
#         [0.9553, 0.0447]], dtype=torch.float64)
#
# Al mio arrivo rilevo mta regolarmente funzionante senza alcun fuori servizio o anomalia presente.  Eseguita pulizia apparato di versamento contanti.  Verifiche corretto funzionamento con esito regolare.  Eseguita ispezione lettore di badge alla ricerca di tessera bancomat inceppata co.e segnalato dalla filiale.  Non si rileva alcuna tessera bancomat.
# ['NF ground-truth']
# []
# tensor([[0.9430, 0.0570],
#         [0.9436, 0.0564],
#         [0.9700, 0.0300],
#         [0.9715, 0.0285],
#         [0.9426, 0.0574],
#         [0.9675, 0.0325]], dtype=torch.float64)
#
# Dopo aver atteso apertura della cassaforte, riscontrato motore cassetto deposito fit bloccato. Effettuata sostituzione pezzo, reset apparato e collaudi di funzionamento ok.
# ['CASSETTE ground-truth']
# ['CASSETTE ground-truth']
# tensor([[0.1194, 0.8806],
#         [0.9346, 0.0654],
#         [0.9669, 0.0331],
#         [0.9588, 0.0412],
#         [0.9686, 0.0314],
#         [0.9748, 0.0252]], dtype=torch.float64)
#
# ATM trovato fuori servizio, trovata cinghia principale CT spezzata, sostituito cash transport, eseguite diverse prove con esito positivo, ATM in regolare funzionamento.
# ['CT ground-truth']
# ['CT ground-truth']
# tensor([[0.9155, 0.0845],
#         [0.0757, 0.9243],
#         [0.9073, 0.0927],
#         [0.9150, 0.0850],
#         [0.9737, 0.0263],
#         [0.9714, 0.0286]], dtype=torch.float64)
#
# Sostituito shutter banconote e pulizia sensori. Test finali con esito positivo
# ['SHUTTER ground-truth']
# ['SHUTTER ground-truth']
# tensor([[0.9736, 0.0264],
#         [0.9678, 0.0322],
#         [0.9709, 0.0291],
#         [0.9573, 0.0427],
#         [0.9618, 0.0382],
#         [0.2105, 0.7895]], dtype=torch.float64)
#
# Rimosso banconote inceppate in ct, probabile carico non conforme non potuto verificare in quanto la guardia non era autorizzata alla rimozione dei sigilli. Attualmente nessun fuori servizio
# ['CT ground-truth']
# ['CT ground-truth']
# tensor([[0.9049, 0.0951],
#         [0.1216, 0.8784],
#         [0.5167, 0.4833],
#         [0.9033, 0.0967],
#         [0.9748, 0.0252],
#         [0.9785, 0.0215]], dtype=torch.float64)
#
# Eseguito controllo e verifiche con esito positivo.  Non si riscontrano anomalie
# []
# []
# tensor([[0.9630, 0.0370],
#         [0.9748, 0.0252],
#         [0.8579, 0.1421],
#         [0.9763, 0.0237],
#         [0.9720, 0.0280],
#         [0.9588, 0.0412]], dtype=torch.float64)
#
# Sostituita precassa escrow ed effettuate prove di funzionamento.
# ['NE ground-truth']
# ['NE ground-truth']
# tensor([[0.9570, 0.0430],
#         [0.9228, 0.0772],
#         [0.0939, 0.9061],
#         [0.9276, 0.0724],
#         [0.9473, 0.0527],
#         [0.9748, 0.0252]], dtype=torch.float64)
#
# G.R. su cash transport piatto AC-B presenta particolari rotti, ciò crea numerosi inceppamenti in fase di dispensazione.
# Atteso apertura cassaforte ore 12:25, e sostituiti piatto AC-B del cash transport.
# Test di funzionamento con esito positivo,  riavvio apparato e verifica ritorno in servizio con esito positivo.
# ['CT ground-truth']
# ['CT ground-truth']
# tensor([[0.9039, 0.0961],
#         [0.0763, 0.9237],
#         [0.9235, 0.0765],
#         [0.9214, 0.0786],
#         [0.9719, 0.0281],
#         [0.9726, 0.0274]], dtype=torch.float64)
#
# Guasto riscontrato: plate ac/b rotto
# Lavoro eseguito: effettuato prelievo e analisi log dispensatore.  Sostituito plate ac/b ed effettuata pulizia dispensatore.  Rimessa in servizio mta in modalità utente e verificato funzionamento con esito positivo
# ['CT ground-truth']
# ['CT ground-truth']
# tensor([[0.8917, 0.1083],
#         [0.1108, 0.8892],
#         [0.8884, 0.1116],
#         [0.8594, 0.1406],
#         [0.9497, 0.0503],
#         [0.9742, 0.0258]], dtype=torch.float64)
#
# Guasto riscontrato: prelievo e versamento fuori servizio, ricircolatore banconote in errore 9515 inceppamento in ST02.
# Lavoro eseguito: rimozione inceppamento n.1 banconota da 50€ in ST02. Controlli visivi e sostituzione plate B. Effettuata pulizia generale GRG e test funzionamento in modalità tecnico con esito positivo. Messa in servizio apparato e verifica funzionamento in modalità utente con esito positivo.
# ['CT ground-truth']
# ['CT ground-truth']
# tensor([[0.8714, 0.1286],
#         [0.1059, 0.8941],
#         [0.6762, 0.3238],
#         [0.8914, 0.1086],
#         [0.9703, 0.0297],
#         [0.9788, 0.0212]], dtype=torch.float64)
#
# Continui inceppamenti nel CT in ST01/ST02/ST04. Dentini e plastiche ok, riscontrata cinghie di trascinamento logore e consumata nei bordi. Effettuato sostituzione CT e prove massive di prelievo e versamento con tool, ok. Test di funzionamento ATM con clientela, ok. Sull' ATM 4504, anomalia lettore assegni, dopo pulizia periferica anomalia rientrata. Prove di lettura con clientela, ok.
# ['CT ground-truth']
# ['CT ground-truth']
# tensor([[0.9108, 0.0892],
#         [0.0803, 0.9197],
#         [0.8636, 0.1364],
#         [0.8910, 0.1090],
#         [0.9689, 0.0311],
#         [0.9736, 0.0264]], dtype=torch.float64)
#
# MTA in regolare servizio utente.
# Effettuata lettura file di LOG.
# Guasto riscontrato: la macchina risulta in servizio utente dal 03/01/2025.
# Ad oggi non si riscontra alcuna anomalia.
# Si riscontra nei giorni precedenti al 03/01 un mancato sfogliamento in RC1.
# Aprendo il cassetto AC-A si riscontrano banconote non genuine (pieghe, orecchie) probabile causa dell'anomalia segnalata.
# Lavoro eseguito: effettuata pulizia Ricircolatore Banconote.
# Effettuata pulizia + lubrificazione RC1/RC2.
# Non si riscontrano ulteriori FS HW.
# Verificate transazioni in modalità utente con riscontro positivo.
#
# ['CASSETTE ground-truth']
# ['CASSETTE ground-truth', 'NF ground-truth']
# tensor([[0.4248, 0.5752],
#         [0.8935, 0.1065],
#         [0.9229, 0.0771],
#         [0.3163, 0.6837],
#         [0.9645, 0.0355],
#         [0.9717, 0.0283]], dtype=torch.float64)
#
# Rimosse banconote inceppate nell' escrow e sostituzione cash transport a causa di continui inceppamenti e piatto  ac rotto.
# Prove ok
# ['CT ground-truth']
# ['CT ground-truth', 'NE ground-truth']
# tensor([[0.9271, 0.0729],
#         [0.2202, 0.7798],
#         [0.2772, 0.7228],
#         [0.9085, 0.0915],
#         [0.9705, 0.0295],
#         [0.9781, 0.0219]], dtype=torch.float64)
#
# Trovato ATM in servizio. Trovate molte banconote accartocciate all'interno del cassetto fit causa rulli di trasporto usurati. Sostituito cassetto effettuate prove tecniche di dispensazione e versamento positive. Rimesso in servizio ATM.
# ['CASSETTE ground-truth']
# ['CASSETTE ground-truth', 'CT ground-truth']
# tensor([[0.2852, 0.7148],
#         [0.2662, 0.7338],
#         [0.9292, 0.0708],
#         [0.9346, 0.0654],
#         [0.9766, 0.0234],
#         [0.9788, 0.0212]], dtype=torch.float64)
#
# All'arrivo in filiale si riscontra una banconote da euro 5 ferma nel NF inferiore ,eseguita rimozione con prove di csch count con esito negativo.
# Impossibile ripristinare, sostituzione NE prove con esito positivo.
# Seguita sostituzione NF inferiore inquanto non sempre le banconote arrivavano in maniera corretta .
# Prove di movimentazione ok .
# Atm in servizio .
# Eseguito prova prelievo di €500 con successivo versamento.
# Tutte le banconote sono state ricircolate .
# ['NE ground-truth']
# ['NF ground-truth']
# tensor([[0.9560, 0.0440],
#         [0.9009, 0.0991],
#         [0.8946, 0.1054],
#         [0.0762, 0.9238],
#         [0.9479, 0.0521],
#         [0.9562, 0.0438]], dtype=torch.float64)
#
# Eseguito revisione dispensatore.
# Rimosso banconote incastrare ,prove di movimentazione banconote con esiti positivo.
# Atm in servizio, prelievo e versamento ok
# []
# ['NE ground-truth']
# tensor([[0.9647, 0.0353],
#         [0.9301, 0.0699],
#         [0.1040, 0.8960],
#         [0.9340, 0.0660],
#         [0.9513, 0.0487],
#         [0.9749, 0.0251]], dtype=torch.float64)
#
# All"arrivo in filiale bancomat correttamente in servizio.
# Atteso apertura cassaforte e controllo accurato della macchina senza trovare alcun tipo di problema.
# Analizzando I log si riscontra un anomalia sui cassetti in data 27,per poi proseguire correttamente a funzionare
# []
# []
# tensor([[0.9467, 0.0533],
#         [0.9510, 0.0490],
#         [0.9704, 0.0296],
#         [0.9573, 0.0427],
#         [0.9701, 0.0299],
#         [0.9437, 0.0563]], dtype=torch.float64)
#
# G.R. errori saltuari plate NF superiore
#
# Ripristino piatto nf sup , test corretto funzionamento con esito positivo
# Messa in servizio apparato
# ['NF ground-truth']
# ['CT ground-truth', 'NF ground-truth']
# tensor([[0.9364, 0.0636],
#         [0.4364, 0.5636],
#         [0.9019, 0.0981],
#         [0.1430, 0.8570],
#         [0.9661, 0.0339],
#         [0.9632, 0.0368]], dtype=torch.float64)
#
# Dalle.molteplici prove di movimentazione effettuate si riscontrano problematiche dovuto al non corretto funzionamento del cassetto da euro 20.
# Sostituzione e configurazione ok,prove ok
# ['CASSETTE ground-truth']
# ['CASSETTE ground-truth']
# tensor([[0.1188, 0.8812],
#         [0.9313, 0.0687],
#         [0.9638, 0.0362],
#         [0.9612, 0.0388],
#         [0.9653, 0.0347],
#         [0.9760, 0.0240]], dtype=torch.float64)
#
# Apparato in fuori servizio prelievo e versamento a causa di un errore sullo sfogliatiore superiore nello specifico lo steker non funziona bene. Effettuata sostituzione dello sfogliatiore pulizia e test funzionali con esito positivo.
# ['NF ground-truth']
# ['NF ground-truth']
# tensor([[0.9597, 0.0403],
#         [0.8995, 0.1005],
#         [0.9116, 0.0884],
#         [0.0726, 0.9274],
#         [0.9579, 0.0421],
#         [0.9523, 0.0477]], dtype=torch.float64)
#
# Guasto riscontrato: banconote accartocciate in porchetta causa versamento corpo estraneo
#
# Lavoro eseguito: rimozione inceppamento e sostituzione cassetto dei €20 usurato
#
# effettuati test sia in modalità tecnico che utente con esito positivo
#
#
# ['NF ground-truth']
# ['CASSETTE ground-truth']
# tensor([[0.1209, 0.8791],
#         [0.9288, 0.0712],
#         [0.9442, 0.0558],
#         [0.9546, 0.0454],
#         [0.9697, 0.0303],
#         [0.9778, 0.0222]], dtype=torch.float64)
#
# Atm fuori servizio anomalia al ricircolatore.
# Eseguita rimozione 6 banconote taglio 50euro.
# Eseguita rimozione graffetta dal NV.
# Eseguita riposizionamento delle cinghie escrow.
# Eseguita pulizia ricircolatore  e rimesso rn servizio ATM.
# Eseguite prove funzionali con successo
# ['NV ground-truth']
# ['NE ground-truth']
# tensor([[0.9655, 0.0345],
#         [0.9412, 0.0588],
#         [0.1840, 0.8160],
#         [0.9496, 0.0504],
#         [0.6738, 0.3262],
#         [0.9767, 0.0233]], dtype=torch.float64)
#
# Trovato apparato bloccato su 2031. Effettuata pulizia, ripristino apparato e test funzionali positivi.
# []
# []
# tensor([[0.9588, 0.0412],
#         [0.9504, 0.0496],
#         [0.9733, 0.0267],
#         [0.9581, 0.0419],
#         [0.9626, 0.0374],
#         [0.9557, 0.0443]], dtype=torch.float64)
#
# Trovato apparato con note validator in errore e lettore assegni non funzionante.
# Effettuata sostituzione di entrambe le periferiche e test funzionali positivi.
# Apparato lasciato in servizio.
# ['NV ground-truth']
# ['NV ground-truth']
# tensor([[0.9658, 0.0342],
#         [0.9721, 0.0279],
#         [0.9542, 0.0458],
#         [0.9583, 0.0417],
#         [0.1555, 0.8445],
#         [0.9683, 0.0317]], dtype=torch.float64)
#
# Total: 0.62 - 4409
# CASSETTE: 0.82 - 929
# CT: 0.84 - 988
# NE: 0.83 - 1183
# NF: 0.82 - 1552
# NV: 0.85 - 624
# SHUTTER: 0.75 - 183
#
#
# TN, FP, FN, TP
#
# {'CASSETTE': [3480, 198, 222, 509], 'CT': [3421, 249, 193, 546], 'NE': [3226, 220, 266, 697], 'NF': [2857, 347, 311, 894], 'NV': [3785, 69, 157, 398], 'SHUTTER': [4226, 40, 70, 73]}
#
# body_learning_rate: (1.9859376752033417e-05, 1.9859376752033417e-05)
# num_epochs: (2, 2)
# batch_size: (6, 6)
# warmup_proportion: 0.2
# sampling_strategy: unique
#                        precision    recall  f1-score   support
#
# CASSETTE ground-truth       0.72      0.70      0.71       731
#       CT ground-truth       0.69      0.74      0.71       739
#       NE ground-truth       0.76      0.72      0.74       963
#       NF ground-truth       0.72      0.74      0.73      1205
#       NV ground-truth       0.85      0.72      0.78       555
#  SHUTTER ground-truth       0.65      0.51      0.57       143
#
#             micro avg       0.74      0.72      0.73      4336
#             macro avg       0.73      0.69      0.71      4336
#          weighted avg       0.74      0.72      0.73      4336
#           samples avg       0.63      0.66      0.63      4336
